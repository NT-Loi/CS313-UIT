# %%
import os
import json
import pandas as pd
from rapidfuzz import process, fuzz

# %%
data_folder = "raw_data"
core_csv = "CORE.csv"
sjr_csv = "scimagojr 2024.csv"

# %%
core_df = pd.read_csv(core_csv)
sjr_df = pd.read_csv(sjr_csv, sep=';')

# %%
years = list(range(2017, 2024+1))
years
# Out:
# [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
#column name of core_df
core_df.columns
# Out:
# Index(['id', 'Title', 'Acronym', 'Source', 'Rank', 'Note', 'Primarily FoR',
#        'Unknown1', 'Unknown2'],
#       dtype='object')

# %%
core_df["Title"] = core_df["Title"].str.strip().str.lower()
sjr_df["Title"] = sjr_df["Title"].str.strip().str.lower()

# %%
core_df["Title"] = core_df["Title"].astype(str).str.strip().str.lower()
sjr_df["Title"] = sjr_df["Title"].astype(str).str.strip().str.lower()

# %%
sjr_df["SJR Best Quartile"].value_counts()
# Out:
# SJR Best Quartile
# Q1    9160
# Q2    7707
# Q3    6928
# Q4    6406
# -      935
# Name: count, dtype: int64

# %%
sjr_df["SJR Best Quartile"] = sjr_df["SJR Best Quartile"].replace("-", None)

# %%
valid_ranks = ["C", "B", "A", "A*"]

core_df["Rank"] = core_df["Rank"].apply(
    lambda x: x if x in valid_ranks else None
)

# %%
print(core_df["Rank"].value_counts())
# Out:
# Rank
# C     362
# B     221
# A     117
# A*     60
# Name: count, dtype: int64

# %%
def find_ranking(venue_name, venue_type, threshold=80):
    """Tìm ranking bằng RapidFuzz dựa vào type và name"""
    venue_name = str(venue_name).strip().lower()

    if venue_type == "conference":
        choices = core_df["Title"].tolist()
        best_match = process.extractOne(venue_name, choices, scorer=fuzz.token_sort_ratio)
        if best_match and best_match[1] >= threshold:
            match_title = best_match[0]
            rank = core_df.loc[core_df["Title"] == match_title, "Rank"].values[0]
            return rank, best_match[1], match_title
    elif venue_type == "journal":
        choices = sjr_df["Title"].tolist()
        best_match = process.extractOne(venue_name, choices, scorer=fuzz.token_sort_ratio)
        if best_match and best_match[1] >= threshold:
            match_title = best_match[0]
            rank = sjr_df.loc[sjr_df["Title"] == match_title, "SJR Best Quartile"].values[0]
            return rank, best_match[1], match_title

    return None, None, None

# %%
# === Duyệt qua tất cả file JSON trong thư mục data/ ===
count_not_found = 0
for year in range(2012, 2025):
    data_folder_year = f"data/{year}"
    for filename in os.listdir(data_folder_year):
        file_path = os.path.join(data_folder_year, filename)
        
        with open(file_path, "r", encoding="utf-8") as f:
            data = json.load(f)

        venue = data.get("venue", {})
        if venue is None:
            data["venue"] = {}
            data["venue"] = {"name": None, "type": None, "ranking": None}
            continue
        name = venue.get("name")
        vtype = venue.get("type")

        if name and vtype:
            rank, score, matched_title = find_ranking(name, vtype)

            if rank:
                data["venue"]["ranking"] = rank
                print(f"✅ {filename}: [{vtype}] '{name}' → '{matched_title}' | Rank: {rank} (Score={score:.1f})")
            else:
                print(f"⚠️ {filename}: Không tìm thấy match phù hợp cho '{name}'",end=" ")
                count_not_found += 1
                if score:
                    print(f"(Score={score:.1f})")
                else:
                    print()
        else:
            print(f"⚠️ {filename}: Khong ton tai loai hinh cong bo")
            count_not_found += 1

        with open(file_path, "w", encoding="utf-8") as f:
            json.dump(data, f, ensure_ascii=False, indent=4)

    print(f"\n🎯 Hoàn tất cập nhật ranking cho các file JSON.")
print(count_not_found)
# Out:
# ✅ 1212.2518.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.2511.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.5625.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2480.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.4674.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3719.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2500.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1211.6566.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.1909.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3903.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.5009.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4929.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5870.json: Không tìm thấy match phù hợp cho 'Asilomar Conference on Signals, Systems and Computers' (Score=94.3)
# ✅ 1212.0695.json: [journal] 'International journal of pattern recognition and artificial intelligence' → 'international journal of pattern recognition and artificial intelligence' | Rank: Q3 (Score=100.0)
# ⚠️ 1211.6496.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5747.json: Không tìm thấy match phù hợp cho 'Symposium on VLSI Circuits'
# ⚠️ 1211.4090.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5217.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3170.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.4384.json: Không tìm thấy match phù hợp cho 'Asilomar Conference on Signals, Systems and Computers' (Score=94.3)
# ⚠️ 1212.3799.json: Không tìm thấy match phù hợp cho 'Youth Academic Annual Conference of Chinese Association of Automation'
# ✅ 1212.2494.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1301.0607.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.0202.json: Không tìm thấy match phù hợp cho 'International Workshop and International Workshop on Approximation, Randomization, and Combinatorial Optimization. Algorithms and Techniques'
# ⚠️ 1211.3812.json: Khong ton tai loai hinh cong bo
# ✅ 1211.4100.json: [journal] 'Mathematical Structures in Computer Science' → 'mathematical structures in computer science' | Rank: Q2 (Score=100.0)
# ⚠️ 1211.3293.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3390.json: Không tìm thấy match phù hợp cho 'The Web Conference'
# ✅ 1211.3128.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ✅ 1212.3682.json: [journal] 'Discrete Applied Mathematics' → 'discrete applied mathematics' | Rank: Q2 (Score=100.0)
# ⚠️ 1212.5777.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4964.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2546.json: Không tìm thấy match phù hợp cho 'International Symposium on Mathematical Morphology and Its Application to Signal and Image Processing'
# ✅ 1212.2449.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.5132.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.7100.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5124.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2475.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.0520.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3375.json: Khong ton tai loai hinh cong bo
# ✅ 1211.6089.json: [journal] 'Discrete & Computational Geometry' → 'discrete and computational geometry' | Rank: Q2 (Score=94.1)
# ✅ 1212.2512.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.2350.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4702.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1046.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0583.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.6715.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6191.json: Không tìm thấy match phù hợp cho 'International Workshop on Systems Software Verification'
# ⚠️ 1212.1471.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3451.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4950.json: Không tìm thấy match phù hợp cho 'Allerton Conference on Communication, Control, and Computing' (Score=80.0)
# ⚠️ 1212.4441.json: Không tìm thấy match phù hợp cho 'International Multi-Topic Conference'
# ✅ 1301.0051.json: [journal] 'Journal of Computational Science and Technology' → 'journal of computer science and technology' | Rank: Q3 (Score=89.9)
# ✅ 1212.3133.json: [conference] 'International Conference on Conceptual Structures' → 'international conference on conceptual modelling' | Rank: A (Score=80.4)
# ⚠️ 1211.6185.json: Không tìm thấy match phù hợp cho 'International Workshop on Systems Software Verification'
# ⚠️ 1212.2671.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6922.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4704.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2470.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.2860.json: [journal] 'PLoS ONE' → 'plos one' | Rank: Q1 (Score=100.0)
# ✅ 1211.5157.json: [journal] 'IEEE Transactions on Vehicular Technology' → 'ieee transactions on vehicular technology' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.6997.json: Không tìm thấy match phù hợp cho 'International Workshop and International Workshop on Approximation, Randomization, and Combinatorial Optimization. Algorithms and Techniques'
# ⚠️ 1212.6935.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4969.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5665.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4499.json: Không tìm thấy match phù hợp cho 'Annales des télécommunications'
# ⚠️ 1211.4654.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4226.json: Khong ton tai loai hinh cong bo
# ✅ 1212.4287.json: [conference] 'International Conference on Parallel Processing' → 'international conference on parallel processing' | Rank: B (Score=100.0)
# ⚠️ 1212.6055.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2281.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.7113.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0526.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5852.json: Không tìm thấy match phù hợp cho 'The Web Conference'
# ✅ 1212.0121.json: [journal] 'Journal of statistical physics' → 'journal of statistical physics' | Rank: Q2 (Score=100.0)
# ✅ 1301.0612.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.0170.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0571.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.0224.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0079.json: [journal] 'Journal of Philosophical Logic' → 'journal of philosophical logic' | Rank: Q1 (Score=100.0)
# ✅ 1212.2485.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.3467.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.2342.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3981.json: [conference] 'IEEE Annual Symposium on Foundations of Computer Science' → 'ieee symposium on foundations of computer science' | Rank: A* (Score=93.3)
# ⚠️ 1211.6195.json: Không tìm thấy match phù hợp cho 'International Workshop on Systems Software Verification'
# ⚠️ 1211.4098.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5736.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3981.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3067.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0047.json: [journal] 'Neurocomputing' → 'neurocomputing' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.5860.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5264.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2303.json: [conference] 'International Symposium on Computational Geometry' → 'international symposium on computational geometry' | Rank: A (Score=100.0)
# ✅ 1212.1121.json: [conference] 'ACM-SIAM Symposium on Discrete Algorithms' → 'acm/siam symposium on discrete algorithms' | Rank: A* (Score=97.6)
# ✅ 1211.6218.json: [journal] 'IEEE Transactions on Communications' → 'ieee transactions on communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.4971.json: Khong ton tai loai hinh cong bo
# ✅ 1212.5374.json: [journal] 'IEEE Signal Processing Letters' → 'ieee signal processing letters' | Rank: Q1 (Score=100.0)
# ✅ 1211.3776.json: [journal] 'Telecommunications Systems' → 'telecommunication systems' | Rank: Q2 (Score=98.0)
# ⚠️ 1212.2686.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0966.json: [journal] 'Applied Categorical Structures' → 'applied categorical structures' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.1963.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3458.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2607.json: Không tìm thấy match phù hợp cho 'American Control Conference'
# ⚠️ 1212.2529.json: Khong ton tai loai hinh cong bo
# ✅ 1212.5139.json: [journal] 'Formal methods in system design' → 'formal methods in system design' | Rank: Q3 (Score=100.0)
# ⚠️ 1212.4675.json: Khong ton tai loai hinh cong bo
# ⚠️ 1301.0559.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1037.json: Không tìm thấy match phù hợp cho 'Web Science Conference'
# ⚠️ 1212.2657.json: Khong ton tai loai hinh cong bo
# ✅ 1211.3934.json: [journal] 'PLoS ONE' → 'plos one' | Rank: Q1 (Score=100.0)
# ✅ 1212.2490.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.6410.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5764.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2701.json: Khong ton tai loai hinh cong bo
# ✅ 1211.5307.json: [journal] 'Discrete Applied Mathematics' → 'discrete applied mathematics' | Rank: Q2 (Score=100.0)
# ✅ 1212.2463.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.5669.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2778.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0752.json: [conference] 'ACM-SIAM Symposium on Discrete Algorithms' → 'acm/siam symposium on discrete algorithms' | Rank: A* (Score=97.6)
# ⚠️ 1211.3666.json: Không tìm thấy match phù hợp cho 'IEEE Conference on Decision and Control'
# ✅ 1212.2396.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ✅ 1301.0592.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.4490.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5098.json: Khong ton tai loai hinh cong bo
# ⚠️ 1301.0048.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5595.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2245.json: [journal] 'Signal, Image and Video Processing' → 'signal, image and video processing' | Rank: Q2 (Score=100.0)
# ⚠️ 1212.6259.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5182.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5701.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3875.json: [conference] 'International Conference on Information and Computation Economies' → 'international conference on computing and informatics' | Rank: C (Score=84.7)
# ⚠️ 1211.2742.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0074.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1100.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3404.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6727.json: Không tìm thấy match phù hợp cho 'Annual Conference Computational Learning Theory'
# ✅ 1212.0421.json: [conference] 'IEEE International Symposium on Parallel & Distributed Processing, Workshops and Phd Forum' → 'ieee international symposium on parallel and distributed processing with applications' | Rank: C (Score=80.0)
# ⚠️ 1211.4705.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3541.json: Khong ton tai loai hinh cong bo
# ✅ 1211.4753.json: [conference] 'International Conference on Artificial Intelligence and Statistics' → 'international conference on artificial intelligence and statistics' | Rank: A (Score=100.0)
# ⚠️ 1212.0200.json: Khong ton tai loai hinh cong bo
# ⚠️ 1301.0039.json: Không tìm thấy match phù hợp cho 'International Workshop on Formal Techniques for Safety-Critical Systems'
# ✅ 1212.2676.json: [conference] 'International Joint Conference on Artificial Intelligence' → 'international joint conference on artificial intelligence' | Rank: A* (Score=100.0)
# ⚠️ 1211.4695.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4113.json: Khong ton tai loai hinh cong bo
# ✅ 1211.5904.json: [journal] 'The international journal of high performance computing applications' → 'international journal of high performance computing applications' | Rank: Q1 (Score=97.0)
# ⚠️ 1212.6808.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1464.json: Không tìm thấy match phù hợp cho 'Web Search and Data Mining'
# ✅ 1212.0025.json: [journal] 'Quantum information & computation' → 'quantum information and computation' | Rank: Q3 (Score=94.1)
# ⚠️ 1212.3023.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6050.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0945.json: [conference] 'International Conference on Pattern Recognition Applications and Methods' → 'international conference on pattern recognition applications and methods' | Rank: C (Score=100.0)
# ✅ 1212.3381.json: [journal] 'IEEE Journal on Selected Areas in Communications' → 'ieee journal on selected areas in communications' | Rank: Q1 (Score=100.0)
# ✅ 1301.0557.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.6711.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4658.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2986.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.7161.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5101.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4507.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3496.json: [journal] 'Computer Physics Communications' → 'computer physics communications' | Rank: Q1 (Score=100.0)
# ✅ 1212.4317.json: [journal] 'Journal of Cryptographic Engineering' → 'journal of cryptographic engineering' | Rank: Q3 (Score=100.0)
# ⚠️ 1301.0044.json: Không tìm thấy match phù hợp cho 'International Workshop on Formal Techniques for Safety-Critical Systems'
# ✅ 1301.0553.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.5442.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6607.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0640.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5197.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2762.json: [conference] 'Parallel Problem Solving from Nature' → 'parallel problem solving from nature' | Rank: A (Score=100.0)
# ⚠️ 1211.4442.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5514.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4258.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0569.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.3162.json: [conference] 'International Conference on Computational Linguistics' → 'international conference on computational linguistics' | Rank: B (Score=100.0)
# ✅ 1212.1298.json: [journal] 'Advances in Mathematics of Communications' → 'advances in mathematics of communications' | Rank: Q2 (Score=100.0)
# ⚠️ 1212.3677.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.7219.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3085.json: Khong ton tai loai hinh cong bo
# ✅ 1212.1682.json: [conference] 'Symposium on the Theory of Computing' → 'acm symposium on theory of computing' | Rank: A* (Score=88.9)
# ⚠️ 1212.5340.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0598.json: [journal] 'Journal of machine learning research' → 'journal of machine learning research' | Rank: Q1 (Score=100.0)
# ✅ 1212.2443.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.3638.json: [conference] 'IEEE Wireless Communications and Networking Conference' → 'ieee wireless communications and networking conference' | Rank: B (Score=100.0)
# ⚠️ 1212.3690.json: Khong ton tai loai hinh cong bo
# ✅ 1211.5350.json: [journal] 'Theoretical Computer Science' → 'theoretical computer science' | Rank: Q2 (Score=100.0)
# ⚠️ 1212.2864.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2064.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3138.json: [conference] 'Annual Meeting of the Cognitive Science Society' → 'annual meeting of the cognitive science society' | Rank: B (Score=100.0)
# ✅ 1211.3643.json: [journal] 'Journal of Logic, Language and Information' → 'journal of logic, language and information' | Rank: Q2 (Score=100.0)
# ⚠️ 1212.2952.json: Không tìm thấy match phù hợp cho 'Annual Symposium on Combinatorial Pattern Matching'
# ✅ 1212.3036.json: [journal] 'Journal of Graph Theory' → 'journal of graph theory' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.6323.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2567.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5983.json: Không tìm thấy match phù hợp cho 'IACR Cryptology ePrint Archive'
# ⚠️ 1212.4804.json: Khong ton tai loai hinh cong bo
# ✅ 1212.5394.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.4373.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3010.json: Khong ton tai loai hinh cong bo
# ✅ 1211.7210.json: [journal] 'Quantum Information Processing' → 'quantum information processing' | Rank: Q2 (Score=100.0)
# ⚠️ 1211.5901.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5629.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5256.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2513.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1211.2776.json: [conference] 'ACM SIGPLAN Conference on Languages, Compilers, and Tools for Embedded Systems' → 'acm sigplan conference on languages, compilers and tools for embedded systems' | Rank: B (Score=99.4)
# ✅ 1212.2497.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.3340.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5636.json: Không tìm thấy match phù hợp cho 'The Web Conference'
# ⚠️ 1212.1406.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3928.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.7283.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6273.json: Khong ton tai loai hinh cong bo
# ✅ 1211.5857.json: [journal] 'IEEE Transactions on Vehicular Technology' → 'ieee transactions on vehicular technology' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.4626.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6036.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0309.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3302.json: Khong ton tai loai hinh cong bo
# ✅ 1212.1223.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.0114.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6193.json: Không tìm thấy match phù hợp cho 'The Web Conference'
# ⚠️ 1211.5418.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3879.json: [conference] 'International Conference on Information and Computation Economies' → 'international conference on computing and informatics' | Rank: C (Score=84.7)
# ⚠️ 1211.5164.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2516.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.1149.json: [journal] 'Journal of Research of the National Institute of Standards and Technology' → 'journal of research of the national institute of standards and technology' | Rank: Q3 (Score=100.0)
# ⚠️ 1212.1651.json: Khong ton tai loai hinh cong bo
# ✅ 1211.3234.json: [conference] 'Workshop on Algorithm Engineering and Experimentation' → 'workshop on algorithm engineering and experiments' | Rank: A (Score=94.1)
# ⚠️ 1212.3341.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2858.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0590.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1301.0595.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.4565.json: [conference] 'Conference on Computer Supported Cooperative Work' → 'acm conference on computer supported cooperative work' | Rank: A (Score=96.1)
# ⚠️ 1211.4038.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5842.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0749.json: Khong ton tai loai hinh cong bo
# ✅ 1212.1346.json: [journal] 'Information and Computation' → 'information and computation' | Rank: Q2 (Score=100.0)
# ⚠️ 1211.2838.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4198.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1611.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6250.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2498.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.5108.json: Không tìm thấy match phù hợp cho 'Language and Automata Theory and Applications'
# ⚠️ 1211.5590.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4940.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1313.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6712.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3418.json: Không tìm thấy match phù hợp cho 'Safety-critical Systems Symposium'
# ⚠️ 1212.0085.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3497.json: Khong ton tai loai hinh cong bo
# ✅ 1212.4777.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ⚠️ 1212.5593.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0277.json: Không tìm thấy match phù hợp cho 'Sequences and Their Applications'
# ✅ 1212.5284.json: [journal] 'EURASIP Journal on Wireless Communications and Networking' → 'eurasip journal on wireless communications and networking' | Rank: Q2 (Score=100.0)
# ⚠️ 1212.0190.json: Không tìm thấy match phù hợp cho 'Canadian Conference on Electrical and Computer Engineering'
# ⚠️ 1212.2425.json: Khong ton tai loai hinh cong bo
# ✅ 1211.5822.json: [journal] 'Journal of Complexity' → 'journal of complexity' | Rank: Q1 (Score=100.0)
# ✅ 1212.5100.json: [journal] 'Designs, Codes and Cryptography' → 'designs, codes, and cryptography' | Rank: Q1 (Score=98.4)
# ✅ 1301.0552.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.5782.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.5400.json: Không tìm thấy match phù hợp cho 'UK Workshop on Computational Intelligence'
# ✅ 1211.4866.json: [conference] 'International Conference on Advances in Computing and Information Technology' → 'ieee international conference on computer and information technology' | Rank: C (Score=87.5)
# ⚠️ 1211.4094.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6813.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4552.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2472.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.5251.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3041.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4867.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2150.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2953.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4179.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3368.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2491.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1301.0574.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.1068.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6039.json: Không tìm thấy match phù hợp cho 'Algorithmic Aspects of Wireless Sensor Networks'
# ⚠️ 1212.0317.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0073.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5679.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3677.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2575.json: Khong ton tai loai hinh cong bo
# ✅ 1211.3729.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ✅ 1211.3439.json: [journal] 'Theory of Computing' → 'theory of computing' | Rank: Q2 (Score=100.0)
# ✅ 1212.0106.json: [journal] 'Algorithmica' → 'algorithmica' | Rank: Q1 (Score=100.0)
# ✅ 1212.0297.json: [conference] 'Symposium on the Theory of Computing' → 'acm symposium on theory of computing' | Rank: A* (Score=88.9)
# ⚠️ 1211.6610.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6903.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6298.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5255.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4683.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3908.json: Khong ton tai loai hinh cong bo
# ✅ 1211.6706.json: [journal] 'Computers in Human Behavior' → 'computers in human behavior' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.5094.json: Khong ton tai loai hinh cong bo
# ✅ 1212.6810.json: [conference] 'European Intelligence and Security Informatics Conference' → 'ieee international conference on intelligence and security informatics' | Rank: C (Score=80.3)
# ⚠️ 1211.6353.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4445.json: Khong ton tai loai hinh cong bo
# ✅ 1211.5184.json: [conference] 'IEEE International Conference on Data Engineering' → 'international conference on data engineering' | Rank: A* (Score=94.6)
# ⚠️ 1211.4392.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4756.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1763.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6207.json: Không tìm thấy match phù hợp cho 'Telecommunications Forum'
# ✅ 1212.3425.json: [journal] 'International Journal of Bifurcation and Chaos in Applied Sciences and Engineering' → 'international journal of applied science and engineering' | Rank: Q3 (Score=81.2)
# ⚠️ 1212.3225.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3471.json: [journal] 'Information Processing Letters' → 'information processing letters' | Rank: Q3 (Score=100.0)
# ⚠️ 1212.3870.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4381.json: Khong ton tai loai hinh cong bo
# ✅ 1211.2756.json: [journal] 'BMC Genomics' → 'bmc genomics' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.7184.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2963.json: [journal] 'Journal of Computer Science' → 'journal of computer science' | Rank: Q4 (Score=100.0)
# ⚠️ 1212.6241.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0562.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.0888.json: Không tìm thấy match phù hợp cho 'International Symposium on Telecommunications'
# ⚠️ 1212.6054.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5352.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6778.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4370.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0217.json: Khong ton tai loai hinh cong bo
# ✅ 1212.5491.json: [conference] 'European Conference on Software Architecture' → 'european conference on software architecture' | Rank: A (Score=100.0)
# ⚠️ 1211.6166.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2477.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.6192.json: Không tìm thấy match phù hợp cho 'International Workshop on Systems Software Verification'
# ⚠️ 1212.3370.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5227.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2547.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4095.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6887.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4414.json: Khong ton tai loai hinh cong bo
# ✅ 1211.4475.json: [journal] 'Journal of Applied Logic' → 'journal of applied logics' | Rank: Q3 (Score=98.0)
# ⚠️ 1212.5473.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3959.json: Khong ton tai loai hinh cong bo
# ✅ 1211.7309.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 1212.6299.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6572.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.2991.json: Khong ton tai loai hinh cong bo
# ✅ 1211.7239.json: [journal] 'IEEE Journal on Selected Areas in Communications' → 'ieee journal on selected areas in communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1301.0041.json: Không tìm thấy match phù hợp cho 'International Workshop on Formal Techniques for Safety-Critical Systems'
# ⚠️ 1211.3299.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4720.json: Khong ton tai loai hinh cong bo
# ✅ 1211.5353.json: [conference] 'Data Compression Conference' → 'data compression conference' | Rank: B (Score=100.0)
# ⚠️ 1301.0045.json: Không tìm thấy match phù hợp cho 'International Workshop on Formal Techniques for Safety-Critical Systems'
# ✅ 1301.0568.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.2005.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6279.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0139.json: [conference] 'Parallel Problem Solving from Nature' → 'parallel problem solving from nature' | Rank: A (Score=100.0)
# ⚠️ 1211.2717.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0597.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.2517.json: [journal] 'Journal of machine learning research' → 'journal of machine learning research' | Rank: Q1 (Score=100.0)
# ✅ 1212.2386.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 1212.3380.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5863.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2496.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.4125.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3544.json: [journal] 'SIAM Journal of Imaging Sciences' → 'siam journal on imaging sciences' | Rank: Q1 (Score=96.9)
# ⚠️ 1211.5252.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0593.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.1098.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.0575.json: Không tìm thấy match phù hợp cho 'Medical Physics (Lancaster)'
# ✅ 1211.6512.json: [journal] 'PLoS ONE' → 'plos one' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.0960.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4914.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2493.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.6187.json: Không tìm thấy match phù hợp cho 'International Workshop on Systems Software Verification'
# ✅ 1211.3063.json: [journal] 'IEEE Transactions on robotics' → 'ieee transactions on robotics' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.5720.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4986.json: Khong ton tai loai hinh cong bo
# ✅ 1212.4915.json: [journal] 'IEEE Transactions on Parallel and Distributed Systems' → 'ieee transactions on parallel and distributed systems' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.5888.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2244.json: [journal] 'International Journal of Unconventional Computing' → 'international journal of unconventional computing' | Rank: Q3 (Score=100.0)
# ✅ 1301.0610.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.2741.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0566.json: [journal] 'Artificial Intelligence' → 'artificial intelligence' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.0146.json: Không tìm thấy match phù hợp cho 'The Web Conference'
# ⚠️ 1211.6466.json: Không tìm thấy match phù hợp cho 'International Computing and Combinatorics Conference' (Score=97.2)
# ⚠️ 1212.3540.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6602.json: Khong ton tai loai hinh cong bo
# ✅ 1211.6664.json: [journal] 'PLoS ONE' → 'plos one' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.6048.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4086.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3890.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6041.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0286.json: [conference] 'International Symposium on Modeling and Optimization in Mobile, Ad-Hoc and Wireless Networks' → 'international symposium on modelling and optimization in mobile, ad hoc, and wireless networks' | Rank: B (Score=94.6)
# ⚠️ 1212.6183.json: Không tìm thấy match phù hợp cho 'Language and Automata Theory and Applications'
# ⚠️ 1212.4751.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3371.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0724.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5454.json: Không tìm thấy match phù hợp cho 'Medicine Meets Virtual Reality'
# ⚠️ 1211.5766.json: Khong ton tai loai hinh cong bo
# ✅ 1212.6276.json: [conference] 'Consumer Communications and Networking Conference' → 'ieee consumer communications and networking conference' | Rank: B (Score=95.1)
# ⚠️ 1211.4290.json: Không tìm thấy match phù hợp cho 'Hot Topics in System Dependability'
# ⚠️ 1211.6847.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2483.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.2309.json: [journal] 'Proceedings of the VLDB Endowment' → 'proceedings of the vldb endowment' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.0220.json: Không tìm thấy match phù hợp cho 'The Sea'
# ⚠️ 1212.6383.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4307.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1625.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4912.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4493.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3534.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4422.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2891.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.1941.json: Không tìm thấy match phù hợp cho 'Computer Science Symposium in Russia' (Score=83.7)
# ✅ 1212.2456.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.4864.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6522.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2453.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.4674.json: Không tìm thấy match phù hợp cho 'International Conference on Communication Systems and Networks' (Score=96.7)
# ⚠️ 1212.2236.json: Không tìm thấy match phù hợp cho 'Conference on Current Trends in Theory and Practice of Informatics'
# ✅ 1212.1754.json: [journal] 'Journal of Scheduling' → 'journal of scheduling' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.5724.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5391.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5116.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0822.json: [journal] 'Physical Review Letters' → 'physical review letters' | Rank: Q1 (Score=100.0)
# ✅ 1211.5108.json: [conference] 'Data Compression Conference' → 'data compression conference' | Rank: B (Score=100.0)
# ⚠️ 1211.4099.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0387.json: Khong ton tai loai hinh cong bo
# ✅ 1212.6500.json: [conference] 'Symposium on Theoretical Aspects of Computer Science' → 'international symposium on theoretical aspects of computer science' | Rank: A (Score=88.1)
# ✅ 1212.1709.json: [journal] 'Journal of the Royal Society Interface' → 'journal of the royal society interface' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.4771.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3998.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2466.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1301.0596.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.6971.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3767.json: [conference] 'International Conference on Learning Representations' → 'international conference on learning representations' | Rank: A* (Score=100.0)
# ✅ 1212.6626.json: [journal] 'IEEE Transactions on Signal Processing' → 'ieee transactions on signal processing' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.0169.json: Khong ton tai loai hinh cong bo
# ✅ 1211.6674.json: [journal] 'Signal Processing' → 'signal processing' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.1855.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2447.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1211.4649.json: [journal] 'IEEE Communications Letters' → 'ieee communications letters' | Rank: Q1 (Score=100.0)
# ✅ 1301.0604.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.5106.json: [journal] 'International journal of algebra and computation' → 'international journal of algebra and computation' | Rank: Q2 (Score=100.0)
# ⚠️ 1212.5599.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2980.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6321.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0591.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.4115.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.7345.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0606.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.6521.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6923.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4464.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0311.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3871.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4692.json: Không tìm thấy match phù hợp cho 'Advanced Computing An International Journal' (Score=82.0)
# ✅ 1212.2446.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.3853.json: Không tìm thấy match phù hợp cho 'Allerton Conference on Communication, Control, and Computing' (Score=80.0)
# ⚠️ 1212.6147.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3444.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4969.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4930.json: Khong ton tai loai hinh cong bo
# ✅ 1212.3501.json: [conference] 'International Conference on Database Theory' → 'international conference on database theory' | Rank: A (Score=100.0)
# ⚠️ 1212.0291.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4709.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4547.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4642.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.6189.json: Không tìm thấy match phù hợp cho 'International Workshop on Systems Software Verification'
# ✅ 1301.0565.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.6831.json: [journal] 'Algorithmica' → 'algorithmica' | Rank: Q1 (Score=100.0)
# ✅ 1211.5259.json: [conference] 'Foundations of Software Science and Computation Structure' → 'foundations of software science and computational structures' | Rank: A (Score=97.4)
# ⚠️ 1211.6190.json: Không tìm thấy match phù hợp cho 'International Workshop on Systems Software Verification'
# ⚠️ 1212.1131.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.3682.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5355.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0207.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0382.json: Khong ton tai loai hinh cong bo
# ✅ 1212.6327.json: [conference] 'International Symposium on Algorithms and Computation' → 'international symposium on algorithms and computation' | Rank: A (Score=100.0)
# ⚠️ 1211.4275.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4237.json: Không tìm thấy match phù hợp cho 'IEEE Conference on Open Systems'
# ⚠️ 1211.5817.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6040.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6531.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2863.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5643.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5067.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0156.json: [conference] 'International Conference on Collaborative Computing' → 'ieee international conference on cluster computing' | Rank: B (Score=83.2)
# ⚠️ 1212.0229.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.4935.json: Khong ton tai loai hinh cong bo
# ✅ 1212.0248.json: [journal] 'Proceedings of the Royal Society A' → 'proceedings of the royal society of victoria' | Rank: Q4 (Score=84.6)
# ⚠️ 1211.5520.json: Khong ton tai loai hinh cong bo
# ✅ 1301.0563.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.0388.json: Khong ton tai loai hinh cong bo
# ✅ 1212.1284.json: [conference] 'International Conference on Advanced Computer Science Applications and Technologies' → 'international conference on data science, technology and applications' | Rank: C (Score=81.6)
# ⚠️ 1212.3906.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4503.json: Khong ton tai loai hinh cong bo
# ✅ 1211.6950.json: [journal] 'IEEE Signal Processing Magazine' → 'ieee signal processing magazine' | Rank: Q1 (Score=100.0)
# ✅ 1301.0572.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1212.0383.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5594.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2479.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.2573.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ✅ 1212.1080.json: [journal] 'IEEE Transactions on Mobile Computing' → 'ieee transactions on mobile computing' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.3466.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5027.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0312.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2457.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1301.0564.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ⚠️ 1211.5329.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2462.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1211.5371.json: [journal] 'Journal of information science and engineering' → 'journal of information science and engineering' | Rank: Q2 (Score=100.0)
# ⚠️ 1211.4517.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5589.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2487.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1212.3654.json: [journal] 'IEEE Transactions on Signal Processing' → 'ieee transactions on signal processing' | Rank: Q1 (Score=100.0)
# ⚠️ 1211.6322.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5738.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.5723.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2960.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3013.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.2875.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2334.json: [journal] 'Computers & electrical engineering' → 'computers and electrical engineering' | Rank: Q1 (Score=94.3)
# ⚠️ 1212.2065.json: Khong ton tai loai hinh cong bo
# ✅ 1212.2445.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1301.0555.json: [conference] 'Conference on Uncertainty in Artificial Intelligence' → 'conference in uncertainty in artificial intelligence' | Rank: A (Score=94.2)
# ✅ 1211.5407.json: [journal] 'International Journal of Service Science Management Engineering and Technology' → 'international journal of service science, management, engineering, and technology' | Rank: Q2 (Score=98.1)
# ⚠️ 1212.4913.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3220.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3074.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3872.json: Khong ton tai loai hinh cong bo
# ✅ 1212.5829.json: [journal] 'IEEE Wireless Communications Letters' → 'ieee wireless communications letters' | Rank: Q1 (Score=100.0)
# ⚠️ 1212.1478.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.3664.json: Khong ton tai loai hinh cong bo
# ⚠️ 1211.4218.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.6303.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5204.json: Khong ton tai loai hinh cong bo
# ⚠️ 1301.0006.json: Không tìm thấy match phù hợp cho 'Online World Conference on Soft Computing in Industrial Applications'
# ⚠️ 1211.6631.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.0087.json: Khong ton tai loai hinh cong bo
# ⚠️ 1212.5650.json: Khong ton tai loai hinh cong bo
# ...
# ✅ 2412.19979.json: [journal] 'IEEE Transactions on Industrial Informatics' → 'ieee transactions on industrial informatics' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.19433.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20225.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19341.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00114.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.10365.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20767.json: Khong ton tai loai hinh cong bo
# ✅ 2501.01985.json: [journal] 'Qeios' → 'eidos' | Rank: Q3 (Score=80.0)
# ⚠️ 2412.20360.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18994.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20087.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.20822.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20574.json: Khong ton tai loai hinh cong bo
# ✅ 2501.00549.json: [journal] 'IEEE Communications Letters' → 'ieee communications letters' | Rank: Q1 (Score=100.0)
# ⚠️ 2501.14735.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18962.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18908.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.04012.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19329.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18933.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18816.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19086.json: Không tìm thấy match phù hợp cho 'BigData Congress [Services Society]'
# ⚠️ 2501.00493.json: Không tìm thấy match phù hợp cho 'Non-Classical Logic. Theory and Applications'
# ✅ 2412.18856.json: [journal] 'IEEE Internet of Things Journal' → 'ieee internet of things journal' | Rank: Q1 (Score=100.0)
# ✅ 2412.20806.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.19201.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20162.json: Khong ton tai loai hinh cong bo
# ✅ 2501.00317.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 2412.20670.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20848.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00501.json: Không tìm thấy match phù hợp cho 'Non-Classical Logic. Theory and Applications'
# ⚠️ 2504.16085.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00241.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00034.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18713.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19993.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 2501.00310.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18984.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19312.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18649.json: Không tìm thấy match phù hợp cho 'IFAC-PapersOnLine' (Score=100.0)
# ⚠️ 2501.03235.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19226.json: [conference] 'International Conference on Advanced Information Networking and Applications' → 'international conference on advanced information networking and applications (was icoin)' | Rank: B (Score=92.7)
# ⚠️ 2501.00087.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18833.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19523.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20390.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18981.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00157.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19209.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 2501.00260.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19192.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20565.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19184.json: Khong ton tai loai hinh cong bo
# ⚠️ 2502.15693.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20987.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19932.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.14768.json: Khong ton tai loai hinh cong bo
# ✅ 2501.03230.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ⚠️ 2501.00160.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19064.json: [journal] 'IEEE Transactions on Knowledge and Data Engineering' → 'ieee transactions on knowledge and data engineering' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.18819.json: Khong ton tai loai hinh cong bo
# ⚠️ 2502.15691.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20116.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18855.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ⚠️ 2412.19675.json: Khong ton tai loai hinh cong bo
# ✅ 2501.00337.json: [conference] 'Symposium on the Theory of Computing' → 'acm symposium on theory of computing' | Rank: A* (Score=88.9)
# ⚠️ 2412.19272.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00208.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19159.json: Khong ton tai loai hinh cong bo
# ⚠️ 2502.07634.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20995.json: Khong ton tai loai hinh cong bo
# ✅ 2412.21205.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 2412.20023.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19259.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20964.json: [journal] 'IEEE Transactions on Pattern Analysis and Machine Intelligence' → 'ieee transactions on pattern analysis and machine intelligence' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.19069.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18500.json: Khong ton tai loai hinh cong bo
# ✅ 2412.18646.json: [journal] 'Theoretical Computer Science' → 'theoretical computer science' | Rank: Q2 (Score=100.0)
# ⚠️ 2501.00628.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00169.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20271.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.14762.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19876.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19696.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19821.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20980.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00511.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ⚠️ 2412.19152.json: Khong ton tai loai hinh cong bo
# ✅ 2501.00243.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 2501.06191.json: Không tìm thấy match phù hợp cho 'European, Mediterranean and Middle Eastern Conference on Information Systems'
# ⚠️ 2412.19444.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19804.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20273.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18808.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18522.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20018.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19256.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20341.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 2412.20391.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20701.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ⚠️ 2412.20721.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00037.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19033.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19053.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19913.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20427.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19206.json: [conference] 'Computer Vision and Pattern Recognition' → 'ieee conference on computer vision and pattern recognition' | Rank: A* (Score=80.4)
# ✅ 2501.14760.json: [journal] 'International Journal of Disaster Risk Reduction' → 'international journal of disaster risk reduction' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.18955.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20556.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19409.json: [conference] 'IEEE/RJS International Conference on Intelligent RObots and Systems' → 'ieee/rsj international conference on intelligent robots and systems' | Rank: A (Score=98.5)
# ✅ 2412.19966.json: [conference] 'International Conference on Computational Linguistics' → 'international conference on computational linguistics' | Rank: B (Score=100.0)
# ⚠️ 2412.19026.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00500.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20254.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00282.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20730.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.01443.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20327.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 2412.18633.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19578.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19500.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.14753.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.01463.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20200.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18631.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18771.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19384.json: Khong ton tai loai hinh cong bo
# ✅ 2501.01969.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 2412.20297.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19031.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20025.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20671.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19871.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20692.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18551.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00065.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.21046.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.21052.json: Không tìm thấy match phù hợp cho 'Conference on Fairness, Accountability and Transparency'
# ⚠️ 2412.20215.json: Không tìm thấy match phù hợp cho 'International Symposium on Circuits and Systems' (Score=94.9)
# ✅ 2501.00637.json: [conference] 'Computer Vision and Pattern Recognition' → 'ieee conference on computer vision and pattern recognition' | Rank: A* (Score=80.4)
# ⚠️ 2412.18485.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20711.json: Khong ton tai loai hinh cong bo
# ✅ 2501.07582.json: [journal] 'ACM Transactions on Graphics' → 'acm transactions on graphics' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.20803.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00039.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19022.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20620.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.10389.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19650.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19906.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18935.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19076.json: Không tìm thấy match phù hợp cho 'Australasian Language Technology Association Workshop' (Score=87.2)
# ⚠️ 2412.19841.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.21030.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20538.json: [conference] 'IEEE International Conference on Automatic Face & Gesture Recognition' → 'ieee international conference on automatic face and gesture recognition' | Rank: B (Score=97.1)
# ⚠️ 2412.19127.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18695.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00175.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20496.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19489.json: Khong ton tai loai hinh cong bo
# ✅ 2412.18820.json: [conference] 'IEEE International Conference on Data Engineering' → 'international conference on data engineering' | Rank: A* (Score=94.6)
# ⚠️ 2501.00578.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19945.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00111.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00379.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19545.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.14754.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20075.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20749.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19449.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20250.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.10374.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19310.json: [journal] 'IEEE Security and Privacy' → 'ieee security and privacy' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.19815.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.18995.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20753.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19200.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19954.json: Khong ton tai loai hinh cong bo
# ✅ 2501.00346.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 2412.18672.json: Khong ton tai loai hinh cong bo
# ✅ 2412.19140.json: [conference] 'International Conference on Computational Linguistics' → 'international conference on computational linguistics' | Rank: B (Score=100.0)
# ⚠️ 2501.00476.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00436.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19676.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19995.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20232.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20020.json: [conference] 'IEEE International Conference on Distributed Computing Systems' → 'international conference on distributed computing systems' | Rank: A (Score=95.8)
# ⚠️ 2412.18589.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20189.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19550.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00214.json: Khong ton tai loai hinh cong bo
# ✅ 2501.00267.json: [journal] 'Multibody system dynamics' → 'multibody system dynamics' | Rank: Q1 (Score=100.0)
# ⚠️ 2501.01430.json: Không tìm thấy match phù hợp cho 'Simulation, Modeling, and Programming for Autonomous Robots'
# ⚠️ 2412.20115.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20834.json: [conference] 'International Conference on Computational Linguistics' → 'international conference on computational linguistics' | Rank: B (Score=100.0)
# ⚠️ 2412.20226.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20275.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.10394.json: Khong ton tai loai hinh cong bo
# ✅ 2501.00298.json: [conference] 'IEEE/ACM International Symposium on Code Generation and Optimization' → 'international symposium on code generation and optimization' | Rank: A (Score=92.9)
# ⚠️ 2412.20916.json: Khong ton tai loai hinh cong bo
# ✅ 2501.01464.json: [conference] 'International Conference on Medical Image Computing and Computer-Assisted Intervention' → 'medical image computing and computer-assisted intervention' | Rank: A (Score=80.6)
# ⚠️ 2412.19005.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20370.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.14772.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20395.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19482.json: Khong ton tai loai hinh cong bo
# ✅ 2412.20004.json: [journal] 'IEEE Transactions on Mobile Computing' → 'ieee transactions on mobile computing' | Rank: Q1 (Score=100.0)
# ⚠️ 2412.19436.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19123.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.20918.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00165.json: Khong ton tai loai hinh cong bo
# ⚠️ 2412.19134.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00645.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.00644.json: Khong ton tai loai hinh cong bo
# ⚠️ 2501.10383.json: Khong ton tai loai hinh cong bo
#
# 🎯 Hoàn tất cập nhật ranking cho các file JSON.
# 10727
