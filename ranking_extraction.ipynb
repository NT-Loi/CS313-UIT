# %%
import os
import json
import pandas as pd
from rapidfuzz import process, fuzz

# %%
data_folder = "raw_data"
core_csv = "CORE.csv"
sjr_csv = "scimagojr 2024.csv"

# %%
core_df = pd.read_csv(core_csv)
sjr_df = pd.read_csv(sjr_csv, sep=';')

# %%
years = list(range(2017, 2024+1))
years
# Out:
# [2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
#column name of core_df
core_df.columns
# Out:
# Index(['id', 'Title', 'Acronym', 'Source', 'Rank', 'Note', 'Primarily FoR',
#        'Unknown1', 'Unknown2'],
#       dtype='object')

# %%
core_df["Title"] = core_df["Title"].str.strip().str.lower()
sjr_df["Title"] = sjr_df["Title"].str.strip().str.lower()

# %%
core_df["Title"] = core_df["Title"].astype(str).str.strip().str.lower()
sjr_df["Title"] = sjr_df["Title"].astype(str).str.strip().str.lower()

# %%
sjr_df["SJR Best Quartile"].value_counts()
# Out:
# SJR Best Quartile
# Q1    9160
# Q2    7707
# Q3    6928
# Q4    6406
# -      935
# Name: count, dtype: int64

# %%
sjr_df["SJR Best Quartile"] = sjr_df["SJR Best Quartile"].replace("-", None)

# %%
valid_ranks = ["C", "B", "A", "A*"]

core_df["Rank"] = core_df["Rank"].apply(
    lambda x: x if x in valid_ranks else None
)

# %%
print(core_df["Rank"].value_counts())
# Out:
# Rank
# C     362
# B     221
# A     117
# A*     60
# Name: count, dtype: int64

# %%
def find_ranking(venue_name, venue_type, threshold=80):
    """Tìm ranking bằng RapidFuzz dựa vào type và name"""
    venue_name = str(venue_name).strip().lower()

    if venue_type == "conference":
        choices = core_df["Title"].tolist()
        best_match = process.extractOne(venue_name, choices, scorer=fuzz.token_sort_ratio)
        if best_match and best_match[1] >= threshold:
            match_title = best_match[0]
            rank = core_df.loc[core_df["Title"] == match_title, "Rank"].values[0]
            return rank, best_match[1], match_title
    elif venue_type == "journal":
        choices = sjr_df["Title"].tolist()
        best_match = process.extractOne(venue_name, choices, scorer=fuzz.token_sort_ratio)
        if best_match and best_match[1] >= threshold:
            match_title = best_match[0]
            rank = sjr_df.loc[sjr_df["Title"] == match_title, "SJR Best Quartile"].values[0]
            return rank, best_match[1], match_title

    return None, None, None

# %%
# === Duyệt qua tất cả file JSON trong thư mục data/ ===
# for year in years:
data_folder_year = "data"
for filename in os.listdir(data_folder_year):
    # print(filename)
    if not filename.endswith(".json"):
        continue
    if filename in ("processed.json", "processing.json"):
        continue


    file_path = os.path.join(data_folder_year, filename)
    # print(f"Processing file: {file_path}")
    with open(file_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    venue = data.get("venue", {})
    if venue is None:
        data["venue"] = {}
        data["venue"] = {"name": None, "type": None, "ranking": None}
        continue
    name = venue.get("name")
    vtype = venue.get("type")

    if name and vtype:
        rank, score, matched_title = find_ranking(name, vtype)

        if rank:
            data["venue"]["ranking"] = rank
            print(f"✅ {filename}: [{vtype}] '{name}' → '{matched_title}' | Rank: {rank} (Score={score:.1f})")
        else:
            print(f"⚠️ {filename}: Không tìm thấy match phù hợp cho '{name}'",end=" ")
            if score:
                print(f"(Score={score:.1f})")
            else:
                print()
    else:
        # if not exist venue info set null for all

        # print(filename)
        data["venue"]["ranking"] = None
        

    with open(file_path, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)

print(f"\n🎯 Hoàn tất cập nhật ranking cho các file JSON.")
# Out:
# ✅ 1912.11745.json: [journal] 'IEEE Transactions on Parallel and Distributed Systems' → 'ieee transactions on parallel and distributed systems' | Rank: Q1 (Score=100.0)
# ✅ 1712.02250.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 1912.12673.json: Không tìm thấy match phù hợp cho 'SoutheastCon'
# ⚠️ 1712.07558.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ✅ 1912.12101.json: [conference] 'IEEE International Conference on Robotics and Automation' → 'ieee international conference on robotics and automation' | Rank: A* (Score=100.0)
# ⚠️ 1912.11494.json: Không tìm thấy match phù hợp cho 'IEEE International Symposium on Biomedical Imaging'
# ✅ 1712.04228.json: [journal] 'Information Processing Letters' → 'information processing letters' | Rank: Q3 (Score=100.0)
# ✅ 1712.08900.json: [journal] 'Computer Vision and Image Understanding' → 'computer vision and image understanding' | Rank: Q1 (Score=100.0)
# ⚠️ 2012.11345.json: Không tìm thấy match phù hợp cho 'European Conference on Antennas and Propagation'
# ✅ 1912.11588.json: [journal] 'Future generations computer systems' → 'future generation computer systems' | Rank: Q1 (Score=98.6)
# ⚠️ 1712.03132.json: Không tìm thấy match phù hợp cho 'American Control Conference'
# ✅ 1712.09162.json: [conference] 'IEEE/RJS International Conference on Intelligent RObots and Systems' → 'ieee/rsj international conference on intelligent robots and systems' | Rank: A (Score=98.5)
# ✅ 1912.13230.json: [conference] 'International Conference on Machine Learning and Applications' → 'international conference on machine learning and applications' | Rank: C (Score=100.0)
# ✅ 2012.10688.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.12676.json: [journal] 'Expert systems with applications' → 'expert systems with applications' | Rank: Q1 (Score=100.0)
# ✅ 2012.11971.json: [journal] 'IEEE Communications Letters' → 'ieee communications letters' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.11000.json: Không tìm thấy match phù hợp cho 'Medical Physics (Lancaster)'
# ✅ 1712.09405.json: [conference] 'International Conference on Language Resources and Evaluation' → 'language resources and evaluation conference' | Rank: B (Score=83.8)
# ✅ 1912.12646.json: [journal] 'Electronic Markets' → 'electronic markets' | Rank: Q1 (Score=100.0)
# ✅ 1712.09392.json: [journal] 'IEEE Transactions on Pattern Analysis and Machine Intelligence' → 'ieee transactions on pattern analysis and machine intelligence' | Rank: Q1 (Score=100.0)
# ✅ 1801.00121.json: [journal] 'IEEE wireless communications' → 'ieee wireless communications' | Rank: Q1 (Score=100.0)
# ✅ 1712.08642.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ✅ 1911.13238.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 2101.03026.json: Không tìm thấy match phù hợp cho 'International Conference on Knowledge Capture'
# ✅ 1801.00308.json: [journal] 'Wireless networks' → 'wireless networks' | Rank: Q2 (Score=100.0)
# ✅ 1912.12637.json: [journal] 'Computational and Applied Mathematics' → 'applied and computational mathematics' | Rank: Q2 (Score=100.0)
# ✅ 1912.11744.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.03943.json: [conference] 'Workshop in Information Security Theory and Practice' → 'workshop in information security theory and practices' | Rank: C (Score=99.0)
# ✅ 1912.12541.json: [conference] 'ACM-SIAM Symposium on Discrete Algorithms' → 'acm/siam symposium on discrete algorithms' | Rank: A* (Score=97.6)
# ✅ 2304.08493.json: [conference] 'IEEE International Conference on Distributed Computing Systems' → 'international conference on distributed computing systems' | Rank: A (Score=95.8)
# ⚠️ 2012.15244.json: Không tìm thấy match phù hợp cho 'MediaEval Benchmarking Initiative for Multimedia Evaluation'
# ✅ 2012.15534.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 1712.05302.json: Không tìm thấy match phù hợp cho 'Integration of AI and OR Techniques in Constraint Programming'
# ✅ 2101.05084.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ✅ 2301.02585.json: [journal] 'Petroleum Research' → 'petroleum research' | Rank: Q1 (Score=100.0)
# ⚠️ 1712.05667.json: Không tìm thấy match phù hợp cho 'International Conference on Scientometrics and Informetrics' (Score=82.5)
# ✅ 2101.02039.json: [journal] 'Social Science Research Network' → 'social science research' | Rank: Q1 (Score=85.2)
# ✅ 1712.06875.json: [journal] 'Communications in nonlinear science & numerical simulation' → 'communications in nonlinear science and numerical simulation' | Rank: Q1 (Score=96.6)
# ✅ 2101.01054.json: [journal] 'CSI Transactions on ICT' → 'transactions in gis' | Rank: Q2 (Score=81.0)
# ✅ 1712.09345.json: [journal] 'Designs, Codes and Cryptography' → 'designs, codes, and cryptography' | Rank: Q1 (Score=98.4)
# ✅ 1912.13194.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.03463.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.12773.json: [conference] 'European Conference on Computer Vision' → 'european conference on computer vision' | Rank: A* (Score=100.0)
# ✅ 2012.13098.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 2301.13005.json: [journal] 'Social Science Research Network' → 'social science research' | Rank: Q1 (Score=85.2)
# ✅ 2012.15463.json: [journal] 'IEEE transactions on multimedia' → 'ieee transactions on multimedia' | Rank: Q1 (Score=100.0)
# ✅ 2301.00023.json: [conference] 'IEEE International Conference on Computer Vision' → 'ieee international conference on computer vision' | Rank: A* (Score=100.0)
# ✅ 1712.03529.json: [conference] 'IEEE International Conference on Data Engineering' → 'international conference on data engineering' | Rank: A* (Score=94.6)
# ⚠️ 1712.08285.json: Không tìm thấy match phù hợp cho 'Distributed Event-Based Systems'
# ✅ 1712.07271.json: [journal] 'International Journal of Computer Vision' → 'international journal of computer vision' | Rank: Q1 (Score=100.0)
# ⚠️ 2301.00321.json: Không tìm thấy match phù hợp cho 'MediaEval Benchmarking Initiative for Multimedia Evaluation'
# ✅ 1912.12843.json: [journal] 'Speech Communication' → 'speech communication' | Rank: Q1 (Score=100.0)
# ✅ 2104.09336.json: [journal] 'Transportation Research Record' → 'transportation research record' | Rank: Q2 (Score=100.0)
# ✅ 2012.10836.json: [journal] 'ACM Journal of Data and Information Quality' → 'journal of data and information quality' | Rank: Q2 (Score=95.1)
# ⚠️ 2301.00066.json: Không tìm thấy match phù hợp cho 'Interspeech'
# ✅ 1712.05128.json: [conference] 'International Conference on Legal Knowledge and Information Systems' → 'international conference on legal knowledge and information systems' | Rank: C (Score=100.0)
# ⚠️ 1712.05512.json: Không tìm thấy match phù hợp cho 'Computing and Communication Workshop and Conference'
# ⚠️ 2301.00008.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ✅ 1912.11730.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.11217.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 2301.00695.json: [conference] 'International Conference on Information Photonics' → 'international conference on information visualisation' | Rank: C (Score=84.3)
# ⚠️ 2101.00130.json: Không tìm thấy match phù hợp cho 'Findings'
# ✅ 1712.02306.json: [conference] 'International Symposium on Information Theory' → 'ieee international symposium on information theory' | Rank: B (Score=94.7)
# ✅ 1712.07863.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ✅ 1912.12717.json: [conference] 'European Conference on Computer Vision' → 'european conference on computer vision' | Rank: A* (Score=100.0)
# ✅ 1912.12244.json: [journal] 'Entropy' → 'entropy' | Rank: Q2 (Score=100.0)
# ✅ 1712.05380.json: [journal] 'Ethics and Information Technology' → 'ethics and information technology' | Rank: Q1 (Score=100.0)
# ✅ 2101.00136.json: [conference] 'International Symposium on Information Theory' → 'ieee international symposium on information theory' | Rank: B (Score=94.7)
# ✅ 1712.03249.json: [conference] 'International Conference on Agents and Artificial Intelligence' → 'international conference on agents and artificial intelligence' | Rank: B (Score=100.0)
# ✅ 2301.00072.json: [conference] 'International Conference on Architectural Support for Programming Languages and Operating Systems' → 'architectural support for programming languages and operating systems' | Rank: A* (Score=83.1)
# ⚠️ 1712.05136.json: Không tìm thấy match phù hợp cho 'International Conference on Wireless Communications and Signal Processing' (Score=81.9)
# ✅ 1801.05853.json: [conference] 'ACM Multimedia' → 'acm multimedia' | Rank: A* (Score=100.0)
# ✅ 2301.00149.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.03158.json: [conference] 'International Symposium on Computational Geometry' → 'international symposium on computational geometry' | Rank: A (Score=100.0)
# ✅ 2301.03413.json: [journal] 'IEEE Embedded Systems Letters' → 'ieee embedded systems letters' | Rank: Q2 (Score=100.0)
# ⚠️ 1912.12167.json: Không tìm thấy match phù hợp cho 'International Electron Devices Meeting'
# ✅ 1712.04059.json: [conference] 'IEEE Conference on Computer Communications' → 'ieee international conference on computer communications' | Rank: A* (Score=85.7)
# ✅ 1912.11929.json: [conference] 'International Conference on Tools and Algorithms for Construction and Analysis of Systems' → 'tools and algorithms for construction and analysis of systems' | Rank: A (Score=81.3)
# ✅ 1912.12576.json: [journal] 'IEEE Transactions on Big Data' → 'ieee transactions on big data' | Rank: Q1 (Score=100.0)
# ✅ 1912.11203.json: [conference] 'International Conference on Automated Planning and Scheduling' → 'international conference on automated planning and scheduling' | Rank: A* (Score=100.0)
# ✅ 1912.10967.json: [journal] 'IEEE Journal on Selected Areas in Information Theory' → 'ieee journal on selected areas in information theory' | Rank: Q1 (Score=100.0)
# ✅ 2012.12619.json: [conference] 'International Conference on Pattern Recognition' → 'international conference on pattern recognition' | Rank: B (Score=100.0)
# ⚠️ 2301.00320.json: Không tìm thấy match phù hợp cho 'MediaEval Benchmarking Initiative for Multimedia Evaluation'
# ✅ 1912.11794.json: [conference] 'IEEE/ACM International Symposium on Cluster, Cloud and Internet Computing' → 'ieee international symposium on cluster, cloud and grid computing' | Rank: B (Score=87.0)
# ⚠️ 1712.03531.json: Không tìm thấy match phù hợp cho 'Global Communications Conference'
# ⚠️ 1802.02178.json: Không tìm thấy match phù hợp cho 'ACM Great Lakes Symposium on VLSI'
# ⚠️ 1912.11126.json: Không tìm thấy match phù hợp cho 'bioRxiv'
# ✅ 1712.08583.json: [conference] 'International Conference on Biometrics' → 'international joint conference on biometrics' | Rank: B (Score=92.7)
# ✅ 1712.08980.json: [journal] 'Computer' → 'computer' | Rank: Q2 (Score=100.0)
# ✅ 1912.12128.json: [journal] 'IEEE Transactions on Smart Grid' → 'ieee transactions on smart grid' | Rank: Q1 (Score=100.0)
# ✅ 2301.00074.json: [conference] 'International Conference on Theory and Applications of Satisfiability Testing' → 'international conference on theory and applications of satisfiability testing' | Rank: A (Score=100.0)
# ⚠️ 2012.14879.json: Không tìm thấy match phù hợp cho 'ACM Symposium on Applied Computing' (Score=100.0)
# ✅ 1801.00194.json: [journal] 'Distributed computing' → 'distributed computing' | Rank: Q1 (Score=100.0)
# ✅ 2012.11911.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ✅ 1712.08416.json: [conference] 'German Conference on Pattern Recognition' → 'international conference on pattern recognition' | Rank: B (Score=87.4)
# ✅ 2301.05058.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.03835.json: [conference] 'International Conference on Learning Representations' → 'international conference on learning representations' | Rank: A* (Score=100.0)
# ✅ 2302.00596.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ✅ 1712.10081.json: [conference] 'IEEE International Conference on Distributed Computing Systems' → 'international conference on distributed computing systems' | Rank: A (Score=95.8)
# ✅ 1912.13023.json: [conference] 'International Conference on Information and Knowledge Management' → 'acm international conference on information and knowledge management' | Rank: A (Score=97.0)
# ⚠️ 1912.11095.json: Không tìm thấy match phù hợp cho 'AAAI/ACM Conference on AI, Ethics, and Society'
# ✅ 2012.11643.json: [conference] 'IEEE International Conference on Tools with Artificial Intelligence' → 'international conference on tools with artificial intelligence' | Rank: B (Score=96.1)
# ✅ 1912.12623.json: [conference] 'International Conference of the Catalan Association for Artificial Intelligence' → 'national conference of the american association for artificial intelligence' | Rank: A* (Score=85.7)
# ✅ 1712.02743.json: [conference] 'German Conference on Pattern Recognition' → 'international conference on pattern recognition' | Rank: B (Score=87.4)
# ✅ 1712.04462.json: [journal] 'Monthly notices of the Royal Astronomical Society' → 'monthly notices of the royal astronomical society' | Rank: Q1 (Score=100.0)
# ✅ 1712.06793.json: [journal] 'IEEE Transactions on Vehicular Technology' → 'ieee transactions on vehicular technology' | Rank: Q1 (Score=100.0)
# ✅ 2012.15321.json: [journal] 'Future generations computer systems' → 'future generation computer systems' | Rank: Q1 (Score=98.6)
# ⚠️ 1712.08428.json: Không tìm thấy match phù hợp cho 'International Conference on Innovative Computing and Cloud Computing'
# ✅ 1712.04127.json: [journal] 'Theoretical Computer Science' → 'theoretical computer science' | Rank: Q2 (Score=100.0)
# ✅ 1912.12348.json: [journal] 'Mechanical systems and signal processing' → 'mechanical systems and signal processing' | Rank: Q1 (Score=100.0)
# ✅ 2012.15112.json: [conference] 'International Conference on Web and Social Media' → 'international conference on web and social media' | Rank: A (Score=100.0)
# ⚠️ 1912.12294.json: Không tìm thấy match phù hợp cho 'Conference on Robot Learning' (Score=100.0)
# ✅ 1912.13472.json: [journal] 'SIAM Journal on Optimization' → 'siam journal on optimization' | Rank: Q1 (Score=100.0)
# ✅ 2301.00050.json: [journal] 'Autonomous Robots' → 'autonomous robots' | Rank: Q1 (Score=100.0)
# ✅ 2012.13504.json: [conference] 'IEEE Wireless Communications and Networking Conference' → 'ieee wireless communications and networking conference' | Rank: B (Score=100.0)
# ✅ 1712.07590.json: [journal] 'IEEE Transactions on Signal Processing' → 'ieee transactions on signal processing' | Rank: Q1 (Score=100.0)
# ✅ 2301.00301.json: [conference] 'International Conference on Artificial Intelligence and Statistics' → 'international conference on artificial intelligence and statistics' | Rank: A (Score=100.0)
# ✅ 1912.11272.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ✅ 1712.03727.json: [journal] 'Image and Vision Computing' → 'image and vision computing' | Rank: Q1 (Score=100.0)
# ✅ 1712.04277.json: [journal] 'Journal of the Franklin Institute' → 'journal of the franklin institute' | Rank: Q1 (Score=100.0)
# ✅ 1912.11617.json: [conference] 'International Symposium on Information Theory' → 'ieee international symposium on information theory' | Rank: B (Score=94.7)
# ✅ 1912.11193.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.05912.json: [conference] 'IEEE Vehicular Technology Conference' → 'ieee vehicular technology conference' | Rank: B (Score=100.0)
# ⚠️ 1712.04295.json: Không tìm thấy match phù hợp cho 'International Conference on Robotics and Mechatronics'
# ⚠️ 2012.15833.json: Không tìm thấy match phù hợp cho 'Findings'
# ✅ 1801.01913.json: [journal] 'Journal of the Royal Society Interface' → 'journal of the royal society interface' | Rank: Q1 (Score=100.0)
# ⚠️ 2012.11022.json: Không tìm thấy match phù hợp cho 'IFAC-PapersOnLine' (Score=100.0)
# ✅ 1912.12044.json: [journal] 'Journal of Algorithms & Computational Technology' → 'journal of algorithms and computational technology' | Rank: Q3 (Score=93.9)
# ✅ 2101.00969.json: [conference] 'Design, Automation and Test in Europe' → 'design, automation and test in europe conference' | Rank: B (Score=87.1)
# ✅ 1712.09001.json: [journal] 'Journal of Intelligent & Fuzzy Systems' → 'journal of intelligent and fuzzy systems' | Rank: Q2 (Score=94.9)
# ⚠️ 1712.08507.json: Không tìm thấy match phù hợp cho 'Information Technology Convergence and Services'
# ✅ 1912.12430.json: [conference] 'Theory and Applications of Models of Computation' → 'conference on theory and applications of models of computation' | Rank: C (Score=87.3)
# ✅ 1712.03665.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.11356.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ✅ 1712.09716.json: [journal] 'Autonomous Robots' → 'autonomous robots' | Rank: Q1 (Score=100.0)
# ✅ 2101.01668.json: [conference] 'IEEE Conference on Computer Communications' → 'ieee international conference on computer communications' | Rank: A* (Score=85.7)
# ⚠️ 2012.14043.json: Không tìm thấy match phù hợp cho 'Annual Conference on Information Sciences and Systems' (Score=92.9)
# ✅ 2012.11384.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.02249.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ✅ 1712.03666.json: [journal] 'Learned Publishing' → 'learned publishing' | Rank: Q1 (Score=100.0)
# ✅ 2301.00126.json: [journal] 'Applied Soft Computing' → 'applied soft computing' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.13031.json: Không tìm thấy match phù hợp cho 'Web Search and Data Mining'
# ✅ 2012.10695.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.02546.json: [journal] 'Applied Artificial Intelligence' → 'applied artificial intelligence' | Rank: Q2 (Score=100.0)
# ✅ 2301.03585.json: [conference] 'IEEE Conference on Communications and Network Security' → 'ieee wireless communications and networking conference' | Rank: B (Score=83.3)
# ✅ 2012.13589.json: [journal] 'Journal of Systems and Software' → 'journal of systems and software' | Rank: Q1 (Score=100.0)
# ✅ 1712.04443.json: [conference] 'International Joint Conference on Artificial Intelligence' → 'international joint conference on artificial intelligence' | Rank: A* (Score=100.0)
# ✅ 1712.06405.json: [journal] 'IEEE journal of biomedical and health informatics' → 'ieee journal of biomedical and health informatics' | Rank: Q1 (Score=100.0)
# ✅ 1912.11519.json: [journal] 'International Journal on Software Tools for Technology Transfer (STTT)' → 'international journal on software tools for technology transfer' | Rank: Q3 (Score=94.7)
# ✅ 1801.00820.json: [conference] 'Annual IEEE International Conference on Pervasive Computing and Communications' → 'ieee international conference on pervasive computing and communications' | Rank: A* (Score=95.3)
# ✅ 1912.11597.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 2301.02580.json: [journal] 'Social Science Research Network' → 'social science research' | Rank: Q1 (Score=85.2)
# ✅ 1912.12700.json: [conference] 'International Symposium on High Performance Computing Systems and Applications' → 'ieee international symposium on network computing and applications' | Rank: B (Score=80.6)
# ⚠️ 1912.10915.json: Không tìm thấy match phù hợp cho 'Proceedings of the International Conference on Speech Prosody' (Score=100.0)
# ⚠️ 2101.00035.json: Không tìm thấy match phù hợp cho 'IEEE Transactions on Transportation Electrification'
# ✅ 1712.05007.json: [conference] 'ACM-SIAM Symposium on Discrete Algorithms' → 'acm/siam symposium on discrete algorithms' | Rank: A* (Score=97.6)
# ✅ 1912.13046.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1801.00202.json: [journal] 'Computers & Operations Research' → 'computers and operations research' | Rank: Q1 (Score=93.8)
# ✅ 1912.13480.json: [journal] 'Entropy' → 'entropy' | Rank: Q2 (Score=100.0)
# ✅ 1712.07299.json: [conference] 'IEEE Symposium Series on Computational Intelligence' → 'ieee symposium on computational intelligence in cyber security' | Rank: C (Score=86.7)
# ⚠️ 2101.05081.json: Không tìm thấy match phù hợp cho 'International Conference on Electrical and Control Engineering'
# ⚠️ 1712.04337.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ⚠️ 1912.13027.json: Không tìm thấy match phù hợp cho 'IEEE International Workshop on Computational Advances in Multi-Sensor Adaptive Processing'
# ✅ 1801.00110.json: [conference] 'IEEE Conference on Computer Communications' → 'ieee international conference on computer communications' | Rank: A* (Score=85.7)
# ✅ 1911.13101.json: [conference] 'International Conference on Automated Planning and Scheduling' → 'international conference on automated planning and scheduling' | Rank: A* (Score=100.0)
# ✅ 1712.10282.json: [conference] 'International Conference on Learning Representations' → 'international conference on learning representations' | Rank: A* (Score=100.0)
# ✅ 1912.12151.json: [conference] 'International Colloquium on Automata, Languages and Programming' → 'international colloquium on automata languages and programming' | Rank: A (Score=99.2)
# ✅ 1912.11420.json: [journal] 'IEEE Transactions on Knowledge and Data Engineering' → 'ieee transactions on knowledge and data engineering' | Rank: Q1 (Score=100.0)
# ⚠️ 2101.05214.json: Không tìm thấy match phù hợp cho 'International Conference on Information and Communicatiaon Technology' (Score=91.2)
# ✅ 1712.04930.json: [journal] 'IEEE Journal on Selected Areas in Communications' → 'ieee journal on selected areas in communications' | Rank: Q1 (Score=100.0)
# ✅ 1912.11211.json: [journal] 'First Monday' → 'first monday' | Rank: Q1 (Score=100.0)
# ⚠️ 1712.02700.json: Không tìm thấy match phù hợp cho 'Asilomar Conference on Signals, Systems and Computers' (Score=94.3)
# ✅ 2101.00098.json: [conference] 'International Conference on Intelligent User Interfaces' → 'international conference on intelligent user interfaces' | Rank: A (Score=100.0)
# ✅ 2301.00183.json: [journal] 'Advances in Complex Systems' → 'advances in complex systems' | Rank: Q2 (Score=100.0)
# ✅ 1712.05171.json: [journal] 'IEEE Wireless Communications Letters' → 'ieee wireless communications letters' | Rank: Q1 (Score=100.0)
# ✅ 2012.11804.json: [conference] 'IEEE Conference on Computer Communications' → 'ieee international conference on computer communications' | Rank: A* (Score=85.7)
# ⚠️ 1712.06435.json: Không tìm thấy match phù hợp cho 'Networks'
# ✅ 1712.06131.json: [journal] 'IEEE Computational Intelligence Magazine' → 'ieee computational intelligence magazine' | Rank: Q1 (Score=100.0)
# ✅ 2012.11878.json: [journal] 'IEEE Transactions on Visualization and Computer Graphics' → 'ieee transactions on visualization and computer graphics' | Rank: Q1 (Score=100.0)
# ⚠️ 1712.03538.json: Không tìm thấy match phù hợp cho 'Conference of the European Chapter of the Association for Computational Linguistics'
# ✅ 1912.11032.json: [conference] 'IEEE International Conference on Robotics and Automation' → 'ieee international conference on robotics and automation' | Rank: A* (Score=100.0)
# ✅ 1912.11785.json: [journal] 'IEEE Transactions on Image Processing' → 'ieee transactions on image processing' | Rank: Q1 (Score=100.0)
# ✅ 2012.12700.json: [journal] 'IEEE Transactions on Software Engineering' → 'ieee transactions on software engineering' | Rank: Q1 (Score=100.0)
# ✅ 1912.11774.json: [conference] 'IEEE International Conference on Robotics and Biomimetics' → 'ieee international conference on robotics and automation' | Rank: A* (Score=88.5)
# ⚠️ 1912.11729.json: Không tìm thấy match phù hợp cho 'Interacción'
# ✅ 2012.12014.json: [conference] 'International Conference on Pattern Recognition' → 'international conference on pattern recognition' | Rank: B (Score=100.0)
# ✅ 1912.13080.json: [conference] 'European Conference on Information Retrieval' → 'european conference on information retrieval' | Rank: A (Score=100.0)
# ✅ 1912.12096.json: [conference] 'IEEE Wireless Communications and Networking Conference' → 'ieee wireless communications and networking conference' | Rank: B (Score=100.0)
# ⚠️ 2301.00057.json: Không tìm thấy match phù hợp cho 'International Conference on Applied Algorithms'
# ⚠️ 1712.04748.json: Không tìm thấy match phù hợp cho 'Global Communications Conference'
# ✅ 1712.03847.json: [journal] 'Proceedings of the National Academy of Sciences of the United States of America' → 'proceedings of the national academy of sciences of the united states of america' | Rank: Q1 (Score=100.0)
# ✅ 1712.08963.json: [conference] 'IEEE Conference on Computer Communications' → 'ieee international conference on computer communications' | Rank: A* (Score=85.7)
# ✅ 2301.00658.json: [journal] 'IEEE Journal on Selected Topics in Signal Processing' → 'ieee journal on selected topics in signal processing' | Rank: Q1 (Score=100.0)
# ✅ 1912.12633.json: [conference] 'International Conference of the Catalan Association for Artificial Intelligence' → 'national conference of the american association for artificial intelligence' | Rank: A* (Score=85.7)
# ✅ 1712.05103.json: [journal] 'SIAM Journal on applied algebra and geometry' → 'siam journal on applied algebra and geometry' | Rank: Q1 (Score=100.0)
# ✅ 2012.13539.json: [journal] 'IEEE Internet of Things Journal' → 'ieee internet of things journal' | Rank: Q1 (Score=100.0)
# ✅ 1912.12016.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.12131.json: [journal] 'Neural Processing Letters' → 'neural processing letters' | Rank: Q2 (Score=100.0)
# ⚠️ 1801.00389.json: Không tìm thấy match phù hợp cho 'International Conference on Advanced Communication Technology'
# ✅ 1912.11847.json: [conference] 'IEEE Vehicular Technology Conference' → 'ieee vehicular technology conference' | Rank: B (Score=100.0)
# ✅ 1712.08307.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 1912.13286.json: Không tìm thấy match phù hợp cho 'Scandinavian Workshop on Algorithm Theory'
# ✅ 1912.11278.json: [conference] 'International Conference on Web and Social Media' → 'international conference on web and social media' | Rank: A (Score=100.0)
# ✅ 2301.00096.json: [journal] 'international journal of engineering trends and technology' → 'international journal of engineering trends and technology' | Rank: Q4 (Score=100.0)
# ✅ 1912.11976.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.11678.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ✅ 2012.13556.json: [journal] 'Nanotechnology' → 'nanotechnology' | Rank: Q2 (Score=100.0)
# ✅ 1801.05854.json: [journal] 'International Journal of Data Science and Analysis' → 'international journal of data science and analytics' | Rank: Q2 (Score=97.0)
# ✅ 2301.03593.json: [journal] 'IEEE Security and Privacy' → 'ieee security and privacy' | Rank: Q1 (Score=100.0)
# ✅ 1712.02974.json: [journal] 'Journal of Computational Mathematics and Data Science' → 'journal of computational mathematics and data science' | Rank: Q2 (Score=100.0)
# ✅ 1912.12688.json: [conference] 'IEEE International Conference on Computer Vision' → 'ieee international conference on computer vision' | Rank: A* (Score=100.0)
# ⚠️ 1912.12831.json: Không tìm thấy match phù hợp cho 'Asilomar Conference on Signals, Systems and Computers' (Score=94.3)
# ⚠️ 1912.12174.json: Không tìm thấy match phù hợp cho 'ISC Conference on Information Security and Cryptology' (Score=89.9)
# ✅ 1912.12413.json: [journal] 'Biometrics' → 'biometrics' | Rank: Q1 (Score=100.0)
# ✅ 1712.05493.json: [conference] 'International Conference on Information Control Systems & Technologies' → 'international conference on web information systems and technologies' | Rank: C (Score=88.4)
# ✅ 1912.12318.json: [journal] 'Physics in Medicine and Biology' → 'physics in medicine and biology' | Rank: Q1 (Score=100.0)
# ✅ 1712.07798.json: [journal] 'Investigative Ophthalmology and Visual Science' → 'investigative ophthalmology and visual science' | Rank: Q1 (Score=100.0)
# ✅ 1912.11170.json: [journal] 'IEEE wireless communications' → 'ieee wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 2101.03140.json: Không tìm thấy match phù hợp cho 'International Conference on Health Information Science' (Score=84.4)
# ✅ 2012.14303.json: [conference] 'IEEE International Geoscience and Remote Sensing Symposium' → 'ieee international geoscience and remote sensing symposium' | Rank: C (Score=100.0)
# ✅ 1712.06897.json: [conference] 'International Conference on Pattern Recognition' → 'international conference on pattern recognition' | Rank: B (Score=100.0)
# ✅ 1712.07745.json: [conference] 'International Joint Conference on Artificial Intelligence' → 'international joint conference on artificial intelligence' | Rank: A* (Score=100.0)
# ⚠️ 1712.09624.json: Không tìm thấy match phù hợp cho 'Symposium on Architectures for Networking and Communications Systems'
# ✅ 1712.08373.json: [journal] 'Information Processing Letters' → 'information processing letters' | Rank: Q3 (Score=100.0)
# ✅ 1911.13104.json: [conference] 'International Symposium on Foundations of Information and Knowledge Systems' → 'international symposium on foundations of intelligent systems' | Rank: C (Score=80.9)
# ✅ 1712.07029.json: [journal] 'PLoS ONE' → 'plos one' | Rank: Q1 (Score=100.0)
# ✅ 2301.00729.json: [journal] 'Decision Analytics' → 'decision analysis' | Rank: Q2 (Score=91.4)
# ✅ 1912.11273.json: [journal] 'ACM Transactions on Computational Logic' → 'acm transactions on computational logic' | Rank: Q2 (Score=100.0)
# ✅ 1912.13287.json: [conference] 'International Symposium on Algorithms and Computation' → 'international symposium on algorithms and computation' | Rank: A (Score=100.0)
# ✅ 1912.11046.json: [conference] 'IEEE International Joint Conference on Neural Network' → 'ieee international joint conference on neural networks' | Rank: B (Score=99.1)
# ⚠️ 1712.09424.json: Không tìm thấy match phù hợp cho 'Technical Symposium on Computer Science Education'
# ⚠️ 1801.00390.json: Không tìm thấy match phù hợp cho 'International Conference on Advanced Communication Technology'
# ✅ 1912.12799.json: [conference] 'British Machine Vision Conference' → 'british machine vision conference' | Rank: A (Score=100.0)
# ✅ 2012.10852.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ✅ 1801.00356.json: [journal] 'IEEE Intelligent Systems' → 'ieee intelligent systems' | Rank: Q1 (Score=100.0)
# ✅ 1712.05403.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 2012.11960.json: [journal] 'International Journal of Machine Learning and Cybernetics' → 'international journal of machine learning and cybernetics' | Rank: Q2 (Score=100.0)
# ✅ 1712.02712.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.06273.json: [conference] 'Machine Translation Summit' → 'machine translation summit' | Rank: C (Score=100.0)
# ✅ 1801.01080.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 2012.12472.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ✅ 2301.03350.json: [journal] 'Journal of Open Research Software' → 'journal of open research software' | Rank: Q1 (Score=100.0)
# ✅ 1712.07217.json: [conference] 'IEEE International Conference on Robotics and Automation' → 'ieee international conference on robotics and automation' | Rank: A* (Score=100.0)
# ⚠️ 1712.05040.json: Không tìm thấy match phù hợp cho 'IEEE Real-Time Systems Symposium'
# ✅ 1712.03991.json: [conference] 'IEEE International Conference on Document Analysis and Recognition' → 'ieee international conference on document analysis and recognition' | Rank: A (Score=100.0)
# ✅ 1712.10167.json: [journal] 'Discrete Applied Mathematics' → 'discrete applied mathematics' | Rank: Q2 (Score=100.0)
# ✅ 1912.11604.json: [journal] 'IEEE transactions on multimedia' → 'ieee transactions on multimedia' | Rank: Q1 (Score=100.0)
# ✅ 2101.00095.json: [journal] 'Chaos, Solitons & Fractals' → 'chaos, solitons and fractals' | Rank: Q1 (Score=92.6)
# ✅ 1912.11831.json: [conference] 'IEEE International Symposium on Network Computing and Applications' → 'ieee international symposium on network computing and applications' | Rank: B (Score=100.0)
# ✅ 1712.08877.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 2012.12627.json: Không tìm thấy match phù hợp cho 'Findings'
# ⚠️ 1912.13214.json: Không tìm thấy match phù hợp cho 'Iranian Conference on Machine Vision and Image Processing' (Score=88.9)
# ✅ 1712.05790.json: [conference] 'European Conference on Computer Vision' → 'european conference on computer vision' | Rank: A* (Score=100.0)
# ✅ 1712.09127.json: [conference] 'IEEE International Joint Conference on Neural Network' → 'ieee international joint conference on neural networks' | Rank: B (Score=99.1)
# ✅ 1912.11746.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.06179.json: [conference] 'International Conference on Intelligent User Interfaces' → 'international conference on intelligent user interfaces' | Rank: A (Score=100.0)
# ✅ 1912.12408.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.05404.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.06250.json: [journal] 'IEEE Internet of Things Journal' → 'ieee internet of things journal' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.12476.json: Không tìm thấy match phù hợp cho 'bioRxiv'
# ✅ 1912.11759.json: [journal] 'IEEE Signal Processing Letters' → 'ieee signal processing letters' | Rank: Q1 (Score=100.0)
# ✅ 1911.13077.json: [conference] 'International Conference on Medical Image Computing and Computer-Assisted Intervention' → 'medical image computing and computer-assisted intervention' | Rank: A (Score=80.6)
# ⚠️ 1912.11975.json: Không tìm thấy match phù hợp cho 'Clinical Natural Language Processing Workshop'
# ✅ 1712.04646.json: [journal] 'Pattern Recognition' → 'pattern recognition' | Rank: Q1 (Score=100.0)
# ✅ 2301.01588.json: [journal] 'Scientific Reports' → 'scientific reports' | Rank: Q1 (Score=100.0)
# ⚠️ 2101.03028.json: Không tìm thấy match phù hợp cho 'International Workshop on Semantic Evaluation'
# ✅ 1912.12370.json: [conference] 'International Conference on Trust, Privacy and Security in Intelligent Systems and Applications' → 'international conference on intelligent systems designs and applications' | Rank: C (Score=80.2)
# ✅ 2301.03374.json: [journal] 'IEEE Communications Magazine' → 'ieee communications magazine' | Rank: Q1 (Score=100.0)
# ✅ 1912.11547.json: [conference] 'ACM Multimedia' → 'acm multimedia' | Rank: A* (Score=100.0)
# ✅ 1912.12106.json: [conference] 'International Conference on Learning Representations' → 'international conference on learning representations' | Rank: A* (Score=100.0)
# ✅ 1712.08107.json: [journal] 'Neurocomputing' → 'neurocomputing' | Rank: Q1 (Score=100.0)
# ✅ 1712.09601.json: [conference] 'International Conference on Theory and Practice of Digital Libraries' → 'international conference on theory and practice of digital libraries (was ecdl until 2010)' | Rank: B (Score=86.1)
# ✅ 1712.06015.json: [conference] 'IEEE International Conference on Cloud Computing' → 'ieee international conference on cloud computing' | Rank: B (Score=100.0)
# ⚠️ 2301.01240.json: Không tìm thấy match phù hợp cho 'IACR Cryptology ePrint Archive'
# ⚠️ 1712.07705.json: Không tìm thấy match phù hợp cho 'ACM SIGACT-SIGMOD-SIGART Symposium on Principles of Database Systems'
# ✅ 2302.03523.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ⚠️ 2301.01208.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ✅ 1912.12049.json: [journal] 'Journal of Computational And Graphical Statistics' → 'journal of computational and graphical statistics' | Rank: Q1 (Score=100.0)
# ✅ 1912.11210.json: [conference] 'International Conference on Informatics, IoT, and Enabling Technologies' → 'international conference on control, decision and information technologies' | Rank: C (Score=81.4)
# ✅ 1712.02474.json: [conference] 'Colloquium on Structural Information & Communication Complexity' → 'international colloquium on structural information and communication complexity' | Rank: B (Score=87.3)
# ⚠️ 1911.13130.json: Không tìm thấy match phù hợp cho 'International Workshop on Signal Processing Advances in Wireless Communications'
# ✅ 2101.01602.json: [conference] 'Computer Vision and Pattern Recognition' → 'ieee conference on computer vision and pattern recognition' | Rank: A* (Score=80.4)
# ⚠️ 1911.13231.json: Không tìm thấy match phù hợp cho 'Lecture Notes in Computer Science' (Score=80.5)
# ⚠️ 1712.06780.json: Không tìm thấy match phù hợp cho 'Asia-Pacific Signal and Information Processing Association Annual Summit and Conference'
# ✅ 1712.08550.json: [conference] 'International Conference on Database and Expert Systems Applications' → 'international conference on database and expert systems applications' | Rank: C (Score=100.0)
# ✅ 1712.03121.json: [conference] 'International Conference on 3D Vision' → 'international conference on machine vision' | Rank: C (Score=86.1)
# ⚠️ 1712.04828.json: Không tìm thấy match phù hợp cho 'Web Search and Data Mining'
# ✅ 2012.10791.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 1712.09645.json: Không tìm thấy match phù hợp cho 'IEEE India Conference'
# ✅ 1712.07325.json: [journal] 'Journal of Multivariate Analysis' → 'journal of multivariate analysis' | Rank: Q1 (Score=100.0)
# ✅ 2012.12040.json: [journal] 'Journal of Computational Physics' → 'journal of computational physics' | Rank: Q1 (Score=100.0)
# ✅ 1912.11620.json: [journal] 'IEEE/ACM Transactions on Networking' → 'ieee/acm transactions on networking' | Rank: Q1 (Score=100.0)
# ✅ 1712.04804.json: [journal] 'IEEE Communications Surveys and Tutorials' → 'ieee communications surveys and tutorials' | Rank: Q1 (Score=100.0)
# ✅ 2012.12142.json: [conference] 'IEEE International Conference on Robotics and Automation' → 'ieee international conference on robotics and automation' | Rank: A* (Score=100.0)
# ⚠️ 2012.12235.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ⚠️ 2301.00152.json: Không tìm thấy match phù hợp cho 'ACM Conference on Hypertext & Social Media'
# ✅ 1712.04910.json: [conference] 'Design, Automation and Test in Europe' → 'design, automation and test in europe conference' | Rank: B (Score=87.1)
# ✅ 2301.01200.json: [journal] 'IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing' → 'ieee journal of selected topics in applied earth observations and remote sensing' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.12738.json: Không tìm thấy match phù hợp cho 'Asilomar Conference on Signals, Systems and Computers' (Score=94.3)
# ✅ 1912.12001.json: [journal] 'Wireless networks' → 'wireless networks' | Rank: Q2 (Score=100.0)
# ⚠️ 1801.00223.json: Không tìm thấy match phù hợp cho 'IEEE International Symposium on Biomedical Imaging'
# ✅ 1912.11405.json: [journal] 'IEEE Geoscience and Remote Sensing Letters' → 'ieee geoscience and remote sensing letters' | Rank: Q1 (Score=100.0)
# ✅ 1912.12125.json: [conference] 'IEEE/RJS International Conference on Intelligent RObots and Systems' → 'ieee/rsj international conference on intelligent robots and systems' | Rank: A (Score=98.5)
# ✅ 1712.02679.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 2301.00188.json: [journal] 'Artificial Intelligence Review' → 'artificial intelligence review' | Rank: Q1 (Score=100.0)
# ✅ 2101.03127.json: [conference] 'International Conference on Machine Learning Technologies' → 'international conference on machine learning' | Rank: A* (Score=87.1)
# ⚠️ 2101.03184.json: Không tìm thấy match phù hợp cho 'International Conference on Health Information Science' (Score=84.4)
# ✅ 1912.10982.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ⚠️ 1911.13162.json: Không tìm thấy match phù hợp cho 'Bildverarbeitung für die Medizin'
# ✅ 1912.12123.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ✅ 1801.08196.json: [journal] 'Social Network Analysis and Mining' → 'social network analysis and mining' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.12610.json: Không tìm thấy match phù hợp cho 'ACM SIGACT-SIGMOD-SIGART Symposium on Principles of Database Systems'
# ✅ 1912.13139.json: [journal] 'IEEE Transactions on Communications' → 'ieee transactions on communications' | Rank: Q1 (Score=100.0)
# ✅ 2012.12160.json: [conference] 'Computer Vision and Pattern Recognition' → 'ieee conference on computer vision and pattern recognition' | Rank: A* (Score=80.4)
# ✅ 1912.11337.json: [journal] 'Chaos, Solitons & Fractals' → 'chaos, solitons and fractals' | Rank: Q1 (Score=92.6)
# ⚠️ 1912.11098.json: Không tìm thấy match phù hợp cho 'Alberto Mendelzon Workshop on Foundations of Data Management'
# ✅ 1712.09097.json: [conference] 'International Conference on Artificial Intelligence and Statistics' → 'international conference on artificial intelligence and statistics' | Rank: A (Score=100.0)
# ✅ 2301.13012.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.13226.json: [conference] 'European Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=100.0)
# ⚠️ 2012.15802.json: Không tìm thấy match phù hợp cho 'Annual Conference Computational Learning Theory'
# ✅ 1912.12665.json: [journal] 'IEEE/ACM Transactions on Networking' → 'ieee/acm transactions on networking' | Rank: Q1 (Score=100.0)
# ✅ 1712.04903.json: [journal] 'Journal of Mathematics and Physics' → 'journal of mathematical physics' | Rank: Q2 (Score=89.2)
# ✅ 1712.08130.json: [conference] 'International Conference on Artificial Intelligence and Statistics' → 'international conference on artificial intelligence and statistics' | Rank: A (Score=100.0)
# ✅ 1712.09713.json: [journal] 'Journal of machine learning research' → 'journal of machine learning research' | Rank: Q1 (Score=100.0)
# ✅ 1712.10261.json: [conference] 'ACM-SIAM Symposium on Discrete Algorithms' → 'acm/siam symposium on discrete algorithms' | Rank: A* (Score=97.6)
# ✅ 1912.11213.json: [journal] 'Physical Review E' → 'physical review e' | Rank: Q2 (Score=100.0)
# ✅ 1912.12031.json: [journal] 'International Journal of Theoretical Physics' → 'international journal of theoretical physics' | Rank: Q3 (Score=100.0)
# ✅ 1712.02767.json: [conference] 'Conference on Intelligent Text Processing and Computational Linguistics' → 'international conference on intelligent text processing and computational linguistics' | Rank: C (Score=91.0)
# ✅ 1912.12924.json: [journal] 'ACM Transactions on Mathematical Software' → 'acm transactions on mathematical software' | Rank: Q1 (Score=100.0)
# ✅ 1712.02223.json: [journal] 'Information Processing & Management' → 'information processing and management' | Rank: Q1 (Score=94.4)
# ✅ 2012.13817.json: [journal] 'IEEE Internet of Things Journal' → 'ieee internet of things journal' | Rank: Q1 (Score=100.0)
# ✅ 1712.06747.json: [conference] 'International Symposium on Computational Geometry' → 'international symposium on computational geometry' | Rank: A (Score=100.0)
# ✅ 1712.04415.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1712.08470.json: [journal] 'IEEE/CAA Journal of Automatica Sinica' → 'ieee/caa journal of automatica sinica' | Rank: Q1 (Score=100.0)
# ✅ 1712.05776.json: [conference] 'International Symposium on Computational Geometry' → 'international symposium on computational geometry' | Rank: A (Score=100.0)
# ✅ 1712.08948.json: [journal] 'Scientific Reports' → 'scientific reports' | Rank: Q1 (Score=100.0)
# ✅ 1712.04833.json: [conference] 'International Workshop on Document Analysis Systems' → 'international workshop on document analysis systems' | Rank: B (Score=100.0)
# ✅ 2301.07485.json: [journal] 'Artificial Intelligence Review' → 'artificial intelligence review' | Rank: Q1 (Score=100.0)
# ✅ 1911.13066.json: [conference] 'International Conference on Neural Information Processing' → 'international conference on neural information processing' | Rank: B (Score=100.0)
# ⚠️ 2012.12730.json: Không tìm thấy match phù hợp cho 'Annual International Conference on Nanoscale Computing and Communication' (Score=84.7)
# ⚠️ 2301.13016.json: Không tìm thấy match phù hợp cho 'Symposium on Field Programmable Gate Arrays' (Score=89.6)
# ✅ 1712.08883.json: [conference] 'International Conference on Artificial Neural Networks' → 'international conference on artificial neural networks' | Rank: C (Score=100.0)
# ⚠️ 1912.12701.json: Không tìm thấy match phù hợp cho 'Scientific Programming'
# ✅ 1712.03290.json: [journal] 'IEEE/ACM Transactions on Networking' → 'ieee/acm transactions on networking' | Rank: Q1 (Score=100.0)
# ...
# ✅ 1712.04175.json: [conference] 'IEEE Conference on Computer Communications' → 'ieee international conference on computer communications' | Rank: A* (Score=85.7)
# ✅ 2101.10066.json: [conference] 'IEEE Conference on Computational Intelligence and Games' → 'conference on games (was computational intelligence and games cig)' | Rank: C (Score=86.0)
# ✅ 2301.00688.json: [journal] 'Social Science Research Network' → 'social science research' | Rank: Q1 (Score=85.2)
# ✅ 1911.13255.json: [journal] 'Journal of Computational Physics' → 'journal of computational physics' | Rank: Q1 (Score=100.0)
# ✅ 1712.03738.json: [conference] 'International Workshop on Document Analysis Systems' → 'international workshop on document analysis systems' | Rank: B (Score=100.0)
# ✅ 1912.11071.json: [conference] 'Symposium on the Theory of Computing' → 'acm symposium on theory of computing' | Rank: A* (Score=88.9)
# ✅ 1712.09391.json: [journal] 'Transactions of the Association for Computational Linguistics' → 'transactions of the association for computational linguistics' | Rank: Q1 (Score=100.0)
# ✅ 2012.13315.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 1912.12854.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ✅ 1712.03659.json: [conference] 'International Conference on Computing, Networking and Communications' → 'international conference on computer communication and networks' | Rank: B (Score=91.6)
# ⚠️ 1912.12144.json: Không tìm thấy match phù hợp cho 'IEEE India Conference'
# ✅ 2301.01202.json: [journal] 'IEEE Transactions on Geoscience and Remote Sensing' → 'ieee transactions on geoscience and remote sensing' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.10986.json: Không tìm thấy match phù hợp cho 'Symposium on Information and Communication Technology'
# ✅ 1712.05929.json: [journal] 'IEEE Network' → 'ieee network' | Rank: Q1 (Score=100.0)
# ✅ 2012.12125.json: [conference] 'International Conference on Machine Learning and Applications' → 'international conference on machine learning and applications' | Rank: C (Score=100.0)
# ⚠️ 1712.05745.json: Không tìm thấy match phù hợp cho 'Critical Information Infrastructures Security'
# ⚠️ 1712.05457.json: Không tìm thấy match phù hợp cho 'Asilomar Conference on Signals, Systems and Computers' (Score=94.3)
# ✅ 1912.12297.json: [journal] 'ACM Transactions on Graphics' → 'acm transactions on graphics' | Rank: Q1 (Score=100.0)
# ✅ 1712.07775.json: [journal] 'Journal of Mathematics and Physics' → 'journal of mathematical physics' | Rank: Q2 (Score=89.2)
# ✅ 1912.12616.json: [journal] 'International Journal of Architectural Computing' → 'international journal of architectural computing' | Rank: Q2 (Score=100.0)
# ✅ 1712.07472.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ✅ 1912.11367.json: [conference] 'Pacific-Asia Conference on Knowledge Discovery and Data Mining' → 'pacific-asia conference on knowledge discovery and data mining' | Rank: B (Score=100.0)
# ✅ 2301.00091.json: [journal] 'Entropy' → 'entropy' | Rank: Q2 (Score=100.0)
# ⚠️ 2101.03141.json: Không tìm thấy match phù hợp cho 'International Conference on Health Information Science' (Score=84.4)
# ✅ 1712.07056.json: [conference] 'IEEE International Symposium on Personal, Indoor and Mobile Radio Communications' → 'ieee international symposium on personal and indoor mobile radio conference' | Rank: B (Score=89.0)
# ⚠️ 2012.15353.json: Không tìm thấy match phù hợp cho 'Workshop on Representation Learning for NLP'
# ✅ 1912.11758.json: [journal] 'The Australasian Journal of Combinatorics' → 'australasian journal of combinatorics' | Rank: Q2 (Score=94.9)
# ✅ 1712.08819.json: [journal] 'Natural Language Engineering' → 'natural language engineering' | Rank: Q1 (Score=100.0)
# ✅ 2012.10704.json: [journal] 'Isprs Journal of Photogrammetry and Remote Sensing' → 'isprs journal of photogrammetry and remote sensing' | Rank: Q1 (Score=100.0)
# ✅ 1712.03112.json: [journal] 'IEEE Transactions on Parallel and Distributed Systems' → 'ieee transactions on parallel and distributed systems' | Rank: Q1 (Score=100.0)
# ✅ 2301.00015.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 1912.12553.json: Không tìm thấy match phù hợp cho 'bioRxiv'
# ✅ 1912.11849.json: [journal] 'Journal of Network and Computer Applications' → 'journal of network and computer applications' | Rank: Q1 (Score=100.0)
# ✅ 2012.13307.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ⚠️ 1712.04818.json: Không tìm thấy match phù hợp cho 'Optical Fiber Communications Conference and Exhibition'
# ✅ 1912.11212.json: [journal] 'Physical Review Research' → 'physical review research' | Rank: Q1 (Score=100.0)
# ✅ 2012.14427.json: [conference] 'IEEE Region 10 Conference' → 'ieee region 10 conference' | Rank: C (Score=100.0)
# ✅ 1712.06763.json: [conference] 'Latin American Symposium on Theoretical Informatics' → 'international symposium on latin american theoretical informatics' | Rank: B (Score=87.9)
# ✅ 1912.12127.json: [journal] 'IEEE Transactions on Biomedical Engineering' → 'ieee transactions on biomedical engineering' | Rank: Q1 (Score=100.0)
# ✅ 1912.11672.json: [journal] 'Computer Physics Communications' → 'computer physics communications' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.12681.json: Không tìm thấy match phù hợp cho 'Conference on Computer Communications Workshops'
# ✅ 1712.06120.json: [journal] 'Annals of Applied Statistics' → 'annals of applied statistics' | Rank: Q1 (Score=100.0)
# ✅ 2101.05216.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ✅ 1912.13120.json: [journal] 'IEEE Transactions on Information Forensics and Security' → 'ieee transactions on information forensics and security' | Rank: Q1 (Score=100.0)
# ✅ 1712.10158.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ✅ 1912.12834.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ✅ 2012.12772.json: [journal] 'Computational optimization and applications' → 'computational optimization and applications' | Rank: Q1 (Score=100.0)
# ⚠️ 2012.12216.json: Không tìm thấy match phù hợp cho 'Information Technology Convergence and Services'
# ✅ 1801.00094.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ✅ 1912.12652.json: [conference] 'International Conference on Electrical Information and Communication Technologies' → 'international conference on information and communication technologies and development' | Rank: C (Score=89.8)
# ✅ 1712.05726.json: [journal] 'IEEE Transactions on Wireless Communications' → 'ieee transactions on wireless communications' | Rank: Q1 (Score=100.0)
# ⚠️ 2301.00345.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ✅ 1911.13289.json: [journal] 'Quantum Machine Intelligence' → 'quantum machine intelligence' | Rank: Q1 (Score=100.0)
# ✅ 1912.13298.json: [journal] 'IEEE Transactions on Computational Imaging' → 'ieee transactions on computational imaging' | Rank: Q1 (Score=100.0)
# ✅ 1912.11567.json: [journal] 'ACM Transactions on Graphics' → 'acm transactions on graphics' | Rank: Q1 (Score=100.0)
# ✅ 1801.04986.json: [journal] 'Applied Mathematics and Computation' → 'applied mathematics and computation' | Rank: Q1 (Score=100.0)
# ✅ 1912.12129.json: [journal] 'Pattern Recognition Letters' → 'pattern recognition letters' | Rank: Q1 (Score=100.0)
# ✅ 1912.11891.json: [journal] 'IEEE Signal Processing Letters' → 'ieee signal processing letters' | Rank: Q1 (Score=100.0)
# ✅ 1912.12609.json: [conference] 'IEEE International Conference on Acoustics, Speech, and Signal Processing' → 'ieee international conference on acoustics, speech and signal processing' | Rank: B (Score=99.3)
# ✅ 1911.13074.json: [journal] 'IEEE Transactions on Parallel and Distributed Systems' → 'ieee transactions on parallel and distributed systems' | Rank: Q1 (Score=100.0)
# ✅ 1912.13413.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.11318.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ⚠️ 1712.10011.json: Không tìm thấy match phù hợp cho 'Allerton Conference on Communication, Control, and Computing' (Score=80.0)
# ✅ 1801.00145.json: [journal] 'IEEE Access' → 'ieee access' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.13143.json: Không tìm thấy match phù hợp cho 'Conference on Learning for Dynamics & Control'
# ✅ 1712.03076.json: [conference] 'International Conference on Evaluation & Assessment in Software Engineering' → 'international conference on evaluation and assessment in software engineering' | Rank: A (Score=97.4)
# ✅ 1912.11038.json: [journal] 'Theoretical Computer Science' → 'theoretical computer science' | Rank: Q2 (Score=100.0)
# ⚠️ 1912.12765.json: Không tìm thấy match phù hợp cho 'International Computing and Combinatorics Conference' (Score=97.2)
# ⚠️ 2103.15654.json: Không tìm thấy match phù hợp cho 'AEIT International Annual Conference'
# ✅ 1912.11947.json: [conference] 'International Conference on Machine Learning and Applications' → 'international conference on machine learning and applications' | Rank: C (Score=100.0)
# ✅ 1912.11545.json: [conference] 'Computer Vision and Pattern Recognition' → 'ieee conference on computer vision and pattern recognition' | Rank: A* (Score=80.4)
# ✅ 2012.11184.json: [journal] 'IEEE Transactions on Cognitive and Developmental Systems' → 'ieee transactions on cognitive and developmental systems' | Rank: Q1 (Score=100.0)
# ✅ 1712.08604.json: [journal] 'International Journal of Computer Assisted Radiology and Surgery' → 'international journal of computer assisted radiology and surgery' | Rank: Q2 (Score=100.0)
# ✅ 2301.00230.json: [journal] 'IEEE transactions on multimedia' → 'ieee transactions on multimedia' | Rank: Q1 (Score=100.0)
# ✅ 1712.03474.json: [conference] 'ACM Multimedia' → 'acm multimedia' | Rank: A* (Score=100.0)
# ✅ 1712.03328.json: [conference] 'International Conference on Utility and Cloud Computing' → 'international conference on cloud computing and services science' | Rank: C (Score=84.0)
# ✅ 1912.11757.json: [journal] 'IEEE Transactions on Big Data' → 'ieee transactions on big data' | Rank: Q1 (Score=100.0)
# ✅ 1712.07570.json: [journal] 'Physical Review Applied' → 'physical review applied' | Rank: Q1 (Score=100.0)
# ✅ 1912.12561.json: [conference] 'IEEE Annual Symposium on Foundations of Computer Science' → 'ieee symposium on foundations of computer science' | Rank: A* (Score=93.3)
# ✅ 1912.12130.json: [journal] 'IEEE Transactions on Smart Grid' → 'ieee transactions on smart grid' | Rank: Q1 (Score=100.0)
# ✅ 1912.11141.json: [conference] 'The European Symposium on Artificial Neural Networks' → 'european symposium on artificial neural networks' | Rank: B (Score=96.0)
# ✅ 1712.06996.json: [conference] 'ACM-SIAM Symposium on Discrete Algorithms' → 'acm/siam symposium on discrete algorithms' | Rank: A* (Score=97.6)
# ✅ 1712.03744.json: [journal] 'IEEE Transactions on Information Theory' → 'ieee transactions on information theory' | Rank: Q1 (Score=100.0)
# ✅ 2012.15775.json: [journal] 'Information Processing Letters' → 'information processing letters' | Rank: Q3 (Score=100.0)
# ✅ 1912.11711.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ✅ 1712.04043.json: [conference] 'International Colloquium on Automata, Languages and Programming' → 'international colloquium on automata languages and programming' | Rank: A (Score=99.2)
# ⚠️ 1712.06240.json: Không tìm thấy match phù hợp cho 'Media Watermarking, Security, and Forensics'
# ✅ 1912.12421.json: [journal] 'IEEE Communications Letters' → 'ieee communications letters' | Rank: Q1 (Score=100.0)
# ✅ 1712.06956.json: [journal] 'International journal of computational geometry and applications' → 'international journal of computational geometry and applications' | Rank: Q4 (Score=100.0)
# ✅ 1712.08734.json: [journal] 'IEEE Transactions on Signal Processing' → 'ieee transactions on signal processing' | Rank: Q1 (Score=100.0)
# ✅ 2101.00150.json: [journal] 'IEEE Journal on Selected Topics in Signal Processing' → 'ieee journal on selected topics in signal processing' | Rank: Q1 (Score=100.0)
# ✅ 1712.10230.json: [journal] 'ACM Transactions on Mathematical Software' → 'acm transactions on mathematical software' | Rank: Q1 (Score=100.0)
# ⚠️ 2301.00070.json: Không tìm thấy match phù hợp cho 'IEEE International Workshop on Factory Communication Systems'
# ✅ 1912.13382.json: [journal] 'Proceedings of the Royal Society A' → 'proceedings of the royal society of victoria' | Rank: Q4 (Score=84.6)
# ⚠️ 1712.07773.json: Không tìm thấy match phù hợp cho 'IEEE Conference on Decision and Control'
# ✅ 1912.13000.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ⚠️ 1912.12602.json: Không tìm thấy match phù hợp cho 'Interspeech'
# ✅ 1712.06028.json: [journal] 'Journal of machine learning research' → 'journal of machine learning research' | Rank: Q1 (Score=100.0)
# ✅ 1712.09742.json: [journal] 'Information Sciences' → 'information sciences' | Rank: Q1 (Score=100.0)
# ✅ 2101.10817.json: [journal] 'Electronics' → 'electronics' | Rank: Q2 (Score=100.0)
# ✅ 1712.10288.json: [journal] 'IEEE Signal Processing Letters' → 'ieee signal processing letters' | Rank: Q1 (Score=100.0)
# ✅ 1912.11491.json: [conference] 'Symposium on the Theory of Computing' → 'acm symposium on theory of computing' | Rank: A* (Score=88.9)
# ✅ 1912.11960.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.13455.json: [conference] 'IEEE International Conference on Software Analysis, Evolution, and Reengineering' → 'ieee international conference on software analysis, evolution and reengineering' | Rank: A (Score=99.4)
# ⚠️ 1912.13464.json: Không tìm thấy match phù hợp cho 'Neural Information Processing Systems'
# ✅ 1912.11713.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ⚠️ 1712.07022.json: Không tìm thấy match phù hợp cho 'IEEE International Symposium on Biomedical Imaging'
# ✅ 1712.09763.json: [conference] 'International Conference on Machine Learning' → 'international conference on machine learning' | Rank: A* (Score=100.0)
# ✅ 1712.03653.json: [journal] 'IEEE Signal Processing Letters' → 'ieee signal processing letters' | Rank: Q1 (Score=100.0)
# ⚠️ 1912.12274.json: Không tìm thấy match phù hợp cho 'bioRxiv'
# ✅ 1712.08976.json: [journal] 'Computer' → 'computer' | Rank: Q2 (Score=100.0)
# ✅ 1912.12373.json: [conference] 'International Conference on Informatics, IoT, and Enabling Technologies' → 'international conference on control, decision and information technologies' | Rank: C (Score=81.4)
# ✅ 1912.11844.json: [conference] 'IEEE Workshop/Winter Conference on Applications of Computer Vision' → 'ieee workshop on applications of computer vision' | Rank: A (Score=84.2)
# ✅ 1912.10832.json: [conference] 'AAAI Conference on Artificial Intelligence' → 'european conference on artificial intelligence' | Rank: A (Score=84.1)
# ✅ 1912.12363.json: [conference] 'Network and Distributed System Security Symposium' → 'usenix network and distributed system security symposium' | Rank: A* (Score=93.3)
#
# 🎯 Hoàn tất cập nhật ranking cho các file JSON.
