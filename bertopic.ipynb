# %%
import pandas as pd

df = pd.read_csv(f"/content/features_2024.csv")
df['text'] = df['title'] + ' ' + df['abstract']
df["year"] = pd.to_datetime(df["published_date"], errors="coerce").dt.year
df.head(5)
# Out:
#     arxiv_id                                              title  \
# 0  1212.2518      Efficient Inference in Large Discrete Domains
# 1  1212.2511         Stochastic complexity of Bayesian networks
# 2  1211.5625  A survey of computational methods for protein ...
# 3  1212.2480  Approximate Inference and Constrained Optimiza...
# 4  1212.4674  Natural Language Understanding Based on Semant...
#
#                                              authors  \
# 0  [{'name': 'R Sharma', 'citations_all': None, '...
# 1  [{'name': 'K Yamazaki', 'citations_all': 708, ...
# 2  [{'name': 'S Srihari', 'citations_all': 3135, ...
# 3  [{'name': 'T Heskes', 'citations_all': 16337, ...
# 4  [{'name': 'H Kong', 'citations_all': None, 'ci...
#
#                                             abstract published_date  \
# 0  In this paper we examine the problem of infere...     2012-10-19
# 1  Bayesian networks are now being used in enormo...     2012-10-19
# 2  Complexes of physically interacting proteins a...     2012-11-24
# 3  Loopy and generalized belief propagation are p...     2012-10-19
# 4  In this paper, we define event expression over...     2012-12-19
#
#      last_revised_date  num_revisions  primary_category  \
# 0  2012-10-19T00:00:00              0                13
# 1  2012-10-19T00:00:00              0                35
# 2  2012-11-24T00:00:00              0                16
# 3  2012-10-19T00:00:00              0                35
# 4  2012-12-19T00:00:00              0                18
#
#                       categories  num_pages  ...  max_h_index  mean_i10_index  \
# 0                      ['cs.AI']        8.0  ...          0.0             0.0
# 1           ['cs.LG', 'stat.ML']        8.0  ...          0.0             0.0
# 2          ['cs.CE', 'q-bio.MN']       27.0  ...          0.0             0.0
# 3  ['cs.LG', 'cs.AI', 'stat.ML']        8.0  ...          0.0             0.0
# 4                      ['cs.CL']        8.0  ...          0.0             0.0
#
#    max_i10_index  slope_papers  slope_citations  num_years_after_publication  \
# 0            0.0             0              0.0                           12
# 1            0.0             0              0.0                           12
# 2            0.0             0              0.0                           12
# 3            0.0             0              0.0                           12
# 4            0.0             0              0.0                           12
#
#   mean_citations_over_years  std_citations_over_years  \
# 0                  0.384615                  0.624926
# 1                  1.307692                  1.065877
# 2                  9.307692                  5.716166
# 3                  4.384615                  1.902972
# 4                  0.000000                  0.000000
#
#                                                 text  year
# 0  Efficient Inference in Large Discrete Domains ...  2012
# 1  Stochastic complexity of Bayesian networks Bay...  2012
# 2  A survey of computational methods for protein ...  2012
# 3  Approximate Inference and Constrained Optimiza...  2012
# 4  Natural Language Understanding Based on Semant...  2012
#
# [5 rows x 41 columns]

# %%
df["arxiv_id"] = df["arxiv_id"].astype(str)
paper_text_df = (
    df.sort_values(["arxiv_id"])
      .assign(text=df["title"] + " " + df["abstract"])
      .groupby("arxiv_id", as_index=False)[["text", "year"]]
      .first()
)

# %%
TRAIN_END = 2019
TEST_BEGIN = 2020

train_df = paper_text_df[paper_text_df['year'] <= TRAIN_END]
test_df = paper_text_df[paper_text_df['year'] >= TEST_BEGIN]
train_df, test_df
# Out:
# (        arxiv_id                                               text  year
#  0      1211.2569  Teichmüller extremal mapping and its applicati...  2012
#  1      1211.2575  A semantic cache for enhancing Web services co...  2012
#  2      1211.2632  Sequential Voronoi diagram calculations using ...  2012
#  3      1211.2636  A memory versus compression ratio trade-off in...  2012
#  4       1211.267  A Mazing 2+eps Approximation for Unsplittable ...  2012
#  ...          ...                                                ...   ...
#  8416  1912.13472  Revisiting Landscape Analysis in Deep Neural N...  2019
#  8417  1912.13477  Interaction laws of monads and comonads We int...  2019
#  8418   1912.1348  On the Difference Between the Information Bott...  2019
#  8419  1912.13487  Winding number for arbitrary integer value in ...  2019
#  8420  1912.13497  Water Supply Prediction Based on Initialized A...  2019
#
#  [8421 rows x 3 columns],
#           arxiv_id                                               text  year
#  8421   2012.10534  PAARS: Privacy Aware Access Regulation System ...  2020
#  8422    2012.1054  Biomedical Knowledge Graph Refinement and Comp...  2020
#  8423   2012.10548  Robustness of Facial Recognition to GAN-based ...  2020
#  8424    2012.1055  Grant-Free Random Access in Machine-Type Commu...  2020
#  8425   2012.10553  An Assessment of GANs for Identity-related App...  2020
#  ...           ...                                                ...   ...
#  13873  2503.04728  Leveraging Large Language Models For Optimized...  2024
#  13874  2503.13448  Recent Developments in Deep Learning-based Aut...  2024
#  13875  2503.13451  2024 Google Scholar Research Interest Ranking ...  2024
#  13876  2504.06268  Assessment of FAIR (Findability, Accessibility...  2024
#  13877  2504.16085  Blockchain-Driven Solutions for Carbon Credit ...  2024
#
#  [5457 rows x 3 columns])

# %%
train_texts = train_df["text"].astype(str).tolist()
test_texts  = test_df["text"].astype(str).tolist()

from bertopic import BERTopic
from sentence_transformers import SentenceTransformer

# sentence embedding model
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

topic_model = BERTopic(
    embedding_model=embedding_model,
    language="english",
    calculate_probabilities=True,
    verbose=True
)

# %%
train_topics, train_probs = topic_model.fit_transform(train_texts)
test_topics, test_probs = topic_model.transform(test_texts)

train_bert_df = train_df.copy()
test_bert_df = test_df.copy()
train_bert_df["topic"] = train_topics
test_bert_df["topic"] = test_topics
# Out:
# 2025-12-14 09:20:38,192 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches:   0%|          | 0/264 [00:00<?, ?it/s]
# 2025-12-14 09:20:59,765 - BERTopic - Embedding - Completed ✓
# 2025-12-14 09:20:59,766 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-12-14 09:21:12,152 - BERTopic - Dimensionality - Completed ✓
# 2025-12-14 09:21:12,153 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-12-14 09:21:17,369 - BERTopic - Cluster - Completed ✓
# 2025-12-14 09:21:17,376 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-12-14 09:21:18,400 - BERTopic - Representation - Completed ✓
# Batches:   0%|          | 0/171 [00:00<?, ?it/s]
# 2025-12-14 09:21:34,586 - BERTopic - Dimensionality - Reducing dimensionality of input embeddings.
# 2025-12-14 09:21:38,398 - BERTopic - Dimensionality - Completed ✓
# 2025-12-14 09:21:38,399 - BERTopic - Clustering - Approximating new points with `hdbscan_model`
# 2025-12-14 09:21:38,701 - BERTopic - Probabilities - Start calculation of probabilities with HDBSCAN
# 2025-12-14 09:21:43,304 - BERTopic - Probabilities - Completed ✓
# 2025-12-14 09:21:43,305 - BERTopic - Cluster - Completed ✓

# %%
topic_model.get_topic_info().head()
# Out:
#    Topic  Count                                         Name  \
# 0     -1   3074                             -1_the_of_to_and
# 1      0    232               0_graphs_graph_vertex_vertices
# 2      1    163                   1_word_language_text_words
# 3      2    137              2_logic_semantics_programs_type
# 4      3    126  3_kernel_classification_learning_classifier
#
#                                       Representation  \
# 0    [the, of, to, and, in, we, for, is, that, this]
# 1  [graphs, graph, vertex, vertices, edge, planar...
# 2  [word, language, text, words, sentence, senten...
# 3  [logic, semantics, programs, type, program, pr...
# 4  [kernel, classification, learning, classifier,...
#
#                                  Representative_Docs
# 0  [Data mining when each data point is a network...
# 1  [On the complexity of the vector connectivity ...
# 2  [Language Without Words: A Pointillist Model f...
# 3  [On the Use of Underspecified Data-Type Semant...
# 4  [Kernel Transform Learning This work proposes ...

# %%
topics_over_time = topic_model.topics_over_time(train_texts, train_df["year"])
# Out:
# 8it [00:05,  1.47it/s]

# %%
trend_df = (
    topics_over_time
    .pivot(index="Timestamp", columns="Topic", values="Frequency")
    .fillna(0)
    .sort_index()
)

topic_growth_rate = trend_df.pct_change().replace([float("inf"), -float("inf")], 0)

growth_long = (
    topic_growth_rate
    .stack()
    .rename("topic_growth_rate")
    .reset_index()
)
growth_long
# Out:
#       Timestamp  Topic  topic_growth_rate
# 0          2013     -1           0.053118
# 1          2013      0           0.142857
# 2          2013      1          -0.333333
# 3          2013      2           0.875000
# 4          2013      3           0.538462
# ...         ...    ...                ...
# 1054       2019    155           0.000000
# 1055       2019    156           0.000000
# 1056       2019    157           0.000000
# 1057       2019    158           0.000000
# 1058       2019    159           0.000000
#
# [1059 rows x 3 columns]

# %%
train_bert_df = train_bert_df.merge(
    growth_long,
    left_on=["year", "topic"],
    right_on=["Timestamp", "Topic"],
    how="left"
)
train_bert_df.drop(columns=["Timestamp", "Topic"], inplace=True)

test_bert_df = test_bert_df.merge(
    growth_long,
    left_on=["year", "topic"],
    right_on=["Timestamp", "Topic"],
    how="left"
)

test_bert_df.drop(columns=["Timestamp", "Topic"], inplace=True)

# %%
train_bert_df
# Out:
#         arxiv_id                                               text  year  \
# 0      1211.2569  Teichmüller extremal mapping and its applicati...  2012
# 1      1211.2575  A semantic cache for enhancing Web services co...  2012
# 2      1211.2632  Sequential Voronoi diagram calculations using ...  2012
# 3      1211.2636  A memory versus compression ratio trade-off in...  2012
# 4       1211.267  A Mazing 2+eps Approximation for Unsplittable ...  2012
# ...          ...                                                ...   ...
# 8416  1912.13472  Revisiting Landscape Analysis in Deep Neural N...  2019
# 8417  1912.13477  Interaction laws of monads and comonads We int...  2019
# 8418   1912.1348  On the Difference Between the Information Bott...  2019
# 8419  1912.13487  Winding number for arbitrary integer value in ...  2019
# 8420  1912.13497  Water Supply Prediction Based on Initialized A...  2019
#
#       topic  topic_growth_rate
# 0        -1                NaN
# 1        68                NaN
# 2         6                NaN
# 3        72                NaN
# 4        74                NaN
# ...     ...                ...
# 8416     34           0.000000
# 8417     -1          61.285714
# 8418     -1          61.285714
# 8419     -1          61.285714
# 8420     -1          61.285714
#
# [8421 rows x 5 columns]

# %%
topic_model.visualize_topics_over_time(topics_over_time)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="64e4c6ff-ff2a-4135-b6bb-dbcff91e3575" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("64e4c6ff-ff2a-4135-b6bb-dbcff91e3575")) {                    Plotly.newPlot(                        "64e4c6ff-ff2a-4135-b6bb-dbcff91e3575",                        [{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: graphs, graph, coloring, vertex, vertices","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: graphs, graph, vertex, edge, vertices","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: graphs, graph, vertex, coloring, vertices","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: graph, graphs, vertex, vertices, edge","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: graphs, graph, vertices, vertex, edge","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: graphs, graph, vertex, planar, ramsey","\u003cb\u003eTopic 0\u003c\u002fb\u003e\u003cbr\u003eWords: graph, graphs, vertices, vertex, minimum"],"marker":{"color":"#E69F00"},"mode":"lines","name":"0_graphs_graph_vertex_vertices","x":[2012,2013,2014,2015,2016,2017,2019],"y":[42,48,45,29,26,23,19],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: words, language, text, grammatical, texts","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: arabic, word, language, corpus, embeddings","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: word, words, language, astell, discourse","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: word, sentence, text, representations, lstm","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: word, text, language, parsing, discourse","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: word, language, words, dialog, corpus","\u003cb\u003eTopic 1\u003c\u002fb\u003e\u003cbr\u003eWords: word, language, text, sentences, words"],"marker":{"color":"#56B4E9"},"mode":"lines","name":"1_word_language_text_words","x":[2012,2013,2014,2015,2016,2017,2019],"y":[12,8,15,14,31,32,51],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: programs, type, logic, semantics, calculus","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: logic, semantics, programs, programming, type","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: logic, middleware, semantics, programming, proof","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: programs, semantics, program, logic, calculus","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: type, logic, programming, asp, languages","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: typestates, intuitionistic, logic, programs, program","\u003cb\u003eTopic 2\u003c\u002fb\u003e\u003cbr\u003eWords: logic, asp, ll, semantics, logics"],"marker":{"color":"#009E73"},"mode":"lines","name":"2_logic_semantics_programs_type","x":[2012,2013,2014,2015,2016,2017,2019],"y":[24,45,18,14,14,8,14],"type":"scatter"},{"hoverinfo":"text","hovertext":["\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: classifiers, classifier, residuals, gaussian, naive","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: class, classification, kernel, learning, instances","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: kernel, manifold, kernels, classification, svm","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: svm, label, classification, kernel, svms","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: kernel, classification, learning, mil, label","\u003cb\u003eTopic 3\u003c\u002fb\u003e\u003cbr\u003eWords: kernel,  ...

# %%
train_bert_df.to_csv("train_bert.csv", index=False)
test_bert_df.to_csv("test_bert.csv", index=False)
